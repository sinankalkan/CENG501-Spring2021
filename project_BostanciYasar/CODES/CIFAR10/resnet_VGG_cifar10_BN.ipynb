# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
import torchvision.transforms as transforms
import sys

import matplotlib.pyplot as plt 
import time   

import os
import argparse

# %% [markdown]
# ### 1.1 Enable GPU
#
# From "Edit -> Notebook Settings -> Hardware accelerator" select GPU. With the following we will specify to PyTorch that we want to use the GPU.

# %%
if torch.cuda.is_available():
  print("Cuda (GPU support) is available and enabled!")
  device = torch.device("cuda")
else:
  print("Cuda (GPU support) is not available :(")
  device = torch.device("cpu")
# Out:
# Cuda (GPU support) is available and enabled!

# %% [markdown]
# ### 2 Model Definition
#
#
# In the original paper there are two different frameworks; ResNet and VGG. In this section, different models for different frameworks are created. However, in the original paper different normalization methods are applied in these frameworks and as mentioned the authors of the paper propose a new method which is called momentum Batch Normalization. In ResNet and VGG frameworks a naive batch normalization block is used and modified according to the proposed Momentum Batch Normalization method. On the other hand, Pytorch functions are used directly for other normalization methods such as Group Normalization, Layer Normalization, Instance Normalization and Batch Normalization for ResNet.

# %% [markdown]
# ### 2.1 ResNet
#
# ResNet18, ResNet34 and ResNet50 architectures are defined according to the original paper as folllows.

# %%
class BasicBlock(nn.Module):
    coefficient = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.coefficient*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.coefficient*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.coefficient*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    coefficient = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.coefficient *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.coefficient*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.coefficient*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.coefficient*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.coefficient*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.coefficient, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.coefficient
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

# %% [markdown]
# ### 2.2 VGG
#
# VGG11 and VGG16 architectures are defined according to the original paper as folllows.

# %%
configuration = {
    'VGG11': [64, 'pool', 128, 'pool', 256, 256, 'pool', 512, 512, 'pool', 512, 512, 'pool'],
    'VGG16': [64, 64, 'pool', 128, 128, 'pool', 256, 256, 256, 'pool', 512, 512, 512, 'pool', 512, 512, 512, 'pool']
}


class VGG(nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(configuration[vgg_name])
        self.classifier = nn.Linear(512, 100)

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

    def _make_layers(self, configuration):
        layers = []
        in_channels = 3
        for x in configuration:
            if x == 'pool':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)

# %% [markdown]
# ## 3 The Dataset
#
# In the original paper authors used CIFAR10 and CIFAR100 datasets. In this section torchvision function is used to load train/test datasets;
#
# *   There are 50000 training images and 10000 test images for  10 different classes for CIFAR10
# *   There are 50000 training images and 10000 test images for 100 different classes for CIFAR100.
#
# In the original paper, authors mentions standard data augmentation and preprocessing techniques are used but any specific parameters were not given in the paper or in the supplementary material of the paper. Therefore, data augmentation and preprocessing techniques are taken from the literature and applied to the datasets.

# %%
# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize((0, 0, 0), (1, 1, 1)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0, 0, 0), (1, 1, 1)),
])

###################
batch_size=32 #batch size (2 per gpu)
m0=32 #ideal batch size
######################


trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2) # 4 gpu

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# ==> Preparing data..
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### 4 Define and Train Model
# In this section user can choose the model between the ResNet18, ResNet34, ResNet50, VGG11 and VGG16 frameworks.

# %% [markdown]
# ### 4.1 Define Loss Function and the Optimizer
#
# Instance is created for the model based on the choice.
#
# In the original paper authors used Stochastic Gradient Descent for the optimization with the momentum 0.9 and weight decay 0.0001 paramaeters set. In the experiments these parameters and optimization method from the paper are preserved.
#
# Since the criterion for the loss function is not specified exactly in the original paper Cross-Entropy Loss method is chosen in the experiments.

# %%
sys.argv=['']
del sys


best_acc = 0  # best test accuracy
start_epoch = 1  


# Model
print('==> Building model..')

#net = VGG('VGG11')
# net = VGG('VGG16')
net = ResNet18()
# net = ResNet34()
# net = ResNet50()

net = net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.1*batch_size/64,
                      momentum=0.9, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 180], gamma=0.1)
# Out:
# ==> Building model..

# %% [markdown]
# ### 4.2 Train the Model
#
# In the original paper, authors propose a new method in order to train large datasets with small batch-sizes for insufficient memory resources. Therefore, in the experiments considerably smaller batch sizes are used and it extends the training times. In order to overcome high training times problem GPU usage becomes a necessity and cuda is used in the experiments with Colab Pro.

# %%
# Training and Accuracy Calculation
def train(verbose=True):
    
    loss_history=[]
    net.train()
    correct = 0
    total = 0
    for epoch in range(start_epoch, start_epoch+epoch_number):
      
      start = time.time()
      for batch_idx, (inputs, targets) in enumerate(trainloader):
          inputs, targets = inputs.to(device), targets.to(device)
          
          optimizer.zero_grad()
          outputs = net(inputs)
          loss = criterion(outputs, targets)
          loss.backward()
          optimizer.step()


          loss_history.append(loss.item()) 

      end = time.time()
      if verbose: print(f'Epoch {epoch} / {epoch_number}: avg. loss of last 5 iterations {np.sum(loss_history[:-6:-1])/5} , Time : {end - start} seconds')            

      global best_acc
      global test_loss
      net.eval()
      test_loss = 0
      correct = 0
      total = 0
      with torch.no_grad():
          for batch_idx, (inputs, targets) in enumerate(testloader):
              inputs, targets = inputs.to(device), targets.to(device)
              outputs = net(inputs)  
              _, predicted = outputs.max(1)
              total += targets.size(0)
              correct += predicted.eq(targets).sum().item()       


      acc = 100.*correct/total
      historyy.append(acc)

      print('acc:',acc,'best_acc:',best_acc)
      if acc > best_acc:
          print('Saving..' )
          
          state = {
              'net': net.state_dict(),
              'acc': acc,
              'epoch': epoch,
          }
          best_acc = acc
          
      print('\n\n') 
      scheduler.step() 
    return loss_history

# %%
epoch_number=200
historyy=[]
losses=[]


loss_history=train()
# Out:
# Epoch 1 / 200: avg. loss of last 5 iterations 1.531023955345154 , Time : 36.28357172012329 seconds
# acc: 41.62 best_acc: 0
# Saving..
#
#
#
# Epoch 2 / 200: avg. loss of last 5 iterations 1.3556695461273194 , Time : 35.925636529922485 seconds
# acc: 54.17 best_acc: 41.62
# Saving..
#
#
#
# Epoch 3 / 200: avg. loss of last 5 iterations 1.1138578414916993 , Time : 35.93851900100708 seconds
# acc: 59.74 best_acc: 54.17
# Saving..
#
#
#
# Epoch 4 / 200: avg. loss of last 5 iterations 1.0570958614349366 , Time : 35.754944801330566 seconds
# acc: 63.16 best_acc: 59.74
# Saving..
#
#
#
# Epoch 5 / 200: avg. loss of last 5 iterations 0.6919335842132568 , Time : 35.89881443977356 seconds
# acc: 69.06 best_acc: 63.16
# Saving..
#
#
#
# Epoch 6 / 200: avg. loss of last 5 iterations 0.7271084308624267 , Time : 35.821507930755615 seconds
# acc: 73.02 best_acc: 69.06
# Saving..
#
#
#
# Epoch 7 / 200: avg. loss of last 5 iterations 0.48877843022346495 , Time : 35.99557709693909 seconds
# acc: 76.6 best_acc: 73.02
# Saving..
#
#
#
# Epoch 8 / 200: avg. loss of last 5 iterations 0.5032034575939178 , Time : 35.90115809440613 seconds
# acc: 78.52 best_acc: 76.6
# Saving..
#
#
#
# Epoch 9 / 200: avg. loss of last 5 iterations 0.5331103146076203 , Time : 35.89442157745361 seconds
# acc: 78.05 best_acc: 78.52
#
#
#
# Epoch 10 / 200: avg. loss of last 5 iterations 0.6763017177581787 , Time : 35.823039293289185 seconds
# acc: 79.42 best_acc: 78.52
# Saving..
#
#
#
# Epoch 11 / 200: avg. loss of last 5 iterations 0.4563738346099854 , Time : 35.9495689868927 seconds
# acc: 78.65 best_acc: 79.42
#
#
#
# Epoch 12 / 200: avg. loss of last 5 iterations 0.5612584948539734 , Time : 35.80678844451904 seconds
# acc: 79.85 best_acc: 79.42
# Saving..
#
#
#
# Epoch 13 / 200: avg. loss of last 5 iterations 0.6521354198455811 , Time : 35.81484365463257 seconds
# acc: 79.9 best_acc: 79.85
# Saving..
#
#
#
# Epoch 14 / 200: avg. loss of last 5 iterations 0.4589442312717438 , Time : 35.83716440200806 seconds
# acc: 84.67 best_acc: 79.9
# Saving..
#
#
#
# Epoch 15 / 200: avg. loss of last 5 iterations 0.4210291773080826 , Time : 35.889532804489136 seconds
# acc: 83.1 best_acc: 84.67
#
#
#
# Epoch 16 / 200: avg. loss of last 5 iterations 0.4580641835927963 , Time : 35.752179861068726 seconds
# acc: 83.06 best_acc: 84.67
#
#
#
# Epoch 17 / 200: avg. loss of last 5 iterations 0.43722028732299806 , Time : 35.902095794677734 seconds
# acc: 83.62 best_acc: 84.67
#
#
#
# Epoch 18 / 200: avg. loss of last 5 iterations 0.3770320475101471 , Time : 35.92906451225281 seconds
# acc: 83.37 best_acc: 84.67
#
#
#
# Epoch 19 / 200: avg. loss of last 5 iterations 0.5221338510513306 , Time : 36.06037259101868 seconds
# acc: 84.68 best_acc: 84.67
# Saving..
#
#
#
# Epoch 20 / 200: avg. loss of last 5 iterations 0.31999497413635253 , Time : 35.98444414138794 seconds
# acc: 85.75 best_acc: 84.68
# Saving..
#
#
#
# Epoch 21 / 200: avg. loss of last 5 iterations 0.3310567528009415 , Time : 35.94327163696289 seconds
# acc: 85.44 best_acc: 85.75
#
#
#
# Epoch 22 / 200: avg. loss of last 5 iterations 0.44053674340248106 , Time : 35.919015645980835 seconds
# acc: 84.71 best_acc: 85.75
#
#
#
# Epoch 23 / 200: avg. loss of last 5 iterations 0.4009600892663002 , Time : 35.81441402435303 seconds
# acc: 85.08 best_acc: 85.75
#
#
#
# Epoch 24 / 200: avg. loss of last 5 iterations 0.29350048303604126 , Time : 35.862273931503296 seconds
# acc: 86.4 best_acc: 85.75
# Saving..
#
#
#
# Epoch 25 / 200: avg. loss of last 5 iterations 0.3241249740123749 , Time : 35.887218713760376 seconds
# acc: 86.47 best_acc: 86.4
# Saving..
#
#
#
# Epoch 26 / 200: avg. loss of last 5 iterations 0.22642747052013873 , Time : 35.85450983047485 seconds
# acc: 86.23 best_acc: 86.47
#
#
#
# Epoch 27 / 200: avg. loss of last 5 iterations 0.3617506891489029 , Time : 35.78493928909302 seconds
# acc: 84.3 best_acc: 86.47
#
#
#
# Epoch 28 / 200: avg. loss of last 5 iterations 0.41640353202819824 , Time : 35.920395851135254 seconds
# acc: 85.84 best_acc: 86.47
#
#
#
# Epoch 29 / 200: avg. loss of last 5 iterations 0.25201048851013186 , Time : 35.84588050842285 seconds
# acc: 85.96 best_acc: 86.47
#
#
#
# Epoch 30 / 200: avg. loss of last 5 iterations 0.2986438900232315 , Time : 35.86025547981262 seconds
# acc: 86.91 best_acc: 86.47
# Saving..
#
#
#
# Epoch 31 / 200: avg. loss of last 5 iterations 0.28561325967311857 , Time : 35.892096757888794 seconds
# acc: 85.56 best_acc: 86.91
#
#
#
# Epoch 32 / 200: avg. loss of last 5 iterations 0.22701562345027923 , Time : 35.809617042541504 seconds
# acc: 87.24 best_acc: 86.91
# Saving..
#
#
#
# Epoch 33 / 200: avg. loss of last 5 iterations 0.6027451753616333 , Time : 35.743152379989624 seconds
# acc: 86.79 best_acc: 87.24
#
#
#
# Epoch 34 / 200: avg. loss of last 5 iterations 0.44082197546958923 , Time : 35.989813804626465 seconds
# acc: 86.44 best_acc: 87.24
#
#
#
# Epoch 35 / 200: avg. loss of last 5 iterations 0.29462787955999375 , Time : 35.80753493309021 seconds
# acc: 84.73 best_acc: 87.24
#
#
#
# Epoch 36 / 200: avg. loss of last 5 iterations 0.27631089091300964 , Time : 35.887118339538574 seconds
# acc: 86.12 best_acc: 87.24
#
#
#
# Epoch 37 / 200: avg. loss of last 5 iterations 0.23185627162456512 , Time : 35.87301826477051 seconds
# acc: 86.96 best_acc: 87.24
#
#
#
# Epoch 38 / 200: avg. loss of last 5 iterations 0.2427219904959202 , Time : 35.77141332626343 seconds
# acc: 86.5 best_acc: 87.24
#
#
#
# Epoch 39 / 200: avg. loss of last 5 iterations 0.3809775412082672 , Time : 35.79070806503296 seconds
# acc: 86.8 best_acc: 87.24
#
#
#
# Epoch 40 / 200: avg. loss of last 5 iterations 0.26095500886440276 , Time : 35.736289978027344 seconds
# acc: 86.7 best_acc: 87.24
#
#
#
# Epoch 41 / 200: avg. loss of last 5 iterations 0.4024696841835976 , Time : 35.891228675842285 seconds
# acc: 86.49 best_acc: 87.24
#
#
#
# Epoch 42 / 200: avg. loss of last 5 iterations 0.2662851274013519 , Time : 35.94325542449951 seconds
# acc: 87.41 best_acc: 87.24
# Saving..
#
#
#
# Epoch 43 / 200: avg. loss of last 5 iterations 0.2332947999238968 , Time : 35.78560471534729 seconds
# acc: 88.17 best_acc: 87.41
# Saving..
#
#
#
# Epoch 44 / 200: avg. loss of last 5 iterations 0.23980077505111694 , Time : 35.80868673324585 seconds
# acc: 86.93 best_acc: 88.17
#
#
#
# Epoch 45 / 200: avg. loss of last 5 iterations 0.32556167542934417 , Time : 35.81670117378235 seconds
# acc: 87.41 best_acc: 88.17
#
#
#
# Epoch 46 / 200: avg. loss of last 5 iterations 0.26815685629844666 , Time : 35.803592681884766 seconds
# acc: 86.05 best_acc: 88.17
#
#
#
# Epoch 47 / 200: avg. loss of last 5 iterations 0.2317190319299698 , Time : 35.848795652389526 seconds
# acc: 86.89 best_acc: 88.17
#
#
#
# Epoch 48 / 200: avg. loss of last 5 iterations 0.32468425631523135 , Time : 35.871989011764526 seconds
# acc: 87.16 best_acc: 88.17
#
#
#
# Epoch 49 / 200: avg. loss of last 5 iterations 0.32104084491729734 , Time : 35.89829897880554 seconds
# acc: 87.68 best_acc: 88.17
#
#
#
# Epoch 50 / 200: avg. loss of last 5 iterations 0.26443828344345094 , Time : 35.77460551261902 seconds
# acc: 84.86 best_acc: 88.17
#
#
#
# Epoch 51 / 200: avg. loss of last 5 iterations 0.22091779559850694 , Time : 35.820234298706055 seconds
# acc: 88.03 best_acc: 88.17
#
#
#
# Epoch 52 / 200: avg. loss of last 5 iterations 0.29829835891723633 , Time : 35.720951557159424 seconds
# acc: 85.17 best_acc: 88.17
#
#
#
# Epoch 53 / 200: avg. loss of last 5 iterations 0.2068670466542244 , Time : 35.95300793647766 seconds
# acc: 88.05 best_acc: 88.17
#
#
#
# Epoch 54 / 200: avg. loss of last 5 iterations 0.326274773478508 , Time : 35.75498175621033 seconds
# acc: 86.67 best_acc: 88.17
#
#
#
# Epoch 55 / 200: avg. loss of last 5 iterations 0.23859800696372985 , Time : 35.76833510398865 seconds
# acc: 88.74 best_acc: 88.17
# Saving..
#
#
#
# Epoch 56 / 200: avg. loss of last 5 iterations 0.28107115626335144 , Time : 35.81360411643982 seconds
# acc: 88.52 best_acc: 88.74
#
#
#
# Epoch 57 / 200: avg. loss of last 5 iterations 0.1475362792611122 , Time : 35.723182678222656 seconds
# acc: 86.05 best_acc: 88.74
#
#
#
# Epoch 58 / 200: avg. loss of last 5 iterations 0.1824188567698002 , Time : 35.89299297332764 seconds
# acc: 88.96 best_acc: 88.74
# Saving..
#
#
#
# Epoch 59 / 200: avg. loss of last 5 iterations 0.233419269323349 , Time : 35.90763807296753 seconds
# acc: 88.46 best_acc: 88.96
#
#
#
# Epoch 60 / 200: avg. loss of last 5 iterations 0.15820165276527404 , Time : 35.78085470199585 seconds
# acc: 88.8 best_acc: 88.96
#
#
#
# Epoch 61 / 200: avg. loss of last 5 iterations 0.0783359620720148 , Time : 35.825217485427856 seconds
# acc: 91.37 best_acc: 88.96
# Saving..
#
#
#
# Epoch 62 / 200: avg. loss of last 5 iterations 0.09176238058134914 , Time : 35.820647954940796 seconds
# acc: 91.45 best_acc: 91.37
# Saving..
#
#
#
# Epoch 63 / 200: avg. loss of last 5 iterations 0.07719043027609587 , Time : 35.7827250957489 seconds
# acc: 91.7 best_acc: 91.45
# Saving..
#
#
#
# Epoch 64 / 200: avg. loss of last 5 iterations 0.07725612167268991 , Time : 35.84619402885437 seconds
# acc: 91.65 best_acc: 91.7
#
#
#
# Epoch 65 / 200: avg. loss of last 5 iterations 0.07855027504265308 , Time : 35.79668045043945 seconds
# acc: 91.69 best_acc: 91.7
#
#
#
# Epoch 66 / 200: avg. loss of last 5 iterations 0.12979873428121208 , Time : 35.830958127975464 seconds
# acc: 91.89 best_acc: 91.7
# Saving..
#
#
#
# Epoch 67 / 200: avg. loss of last 5 iterations 0.06430784808471798 , Time : 35.83708715438843 seconds
# acc: 91.88 best_acc: 91.89
#
#
#
# Epoch 68 / 200: avg. loss of last 5 iterations 0.10409097149968147 , Time : 35.884883403778076 seconds
# acc: 91.68 best_acc: 91.89
#
#
#
# Epoch 69 / 200: avg. loss of last 5 iterations 0.06570428004488349 , Time : 35.743359327316284 seconds
# acc: 91.64 best_acc: 91.89
#
#
#
# Epoch 70 / 200: avg. loss of last 5 iterations 0.10137671120464802 , Time : 35.807190895080566 seconds
# acc: 91.92 best_acc: 91.89
# Saving..
#
#
#
# Epoch 71 / 200: avg. loss of last 5 iterations 0.09705245848745107 , Time : 35.73162603378296 seconds
# acc: 91.86 best_acc: 91.92
#
#
#
# Epoch 72 / 200: avg. loss of last 5 iterations 0.018380442447960377 , Time : 35.83067226409912 seconds
# acc: 91.53 best_acc: 91.92
#
#
#
# Epoch 73 / 200: avg. loss of last 5 iterations 0.050864309538155794 , Time : 35.80844163894653 seconds
# acc: 91.83 best_acc: 91.92
#
#
#
# Epoch 74 / 200: avg. loss of last 5 iterations 0.039842335507273674 , Time : 35.846914768218994 seconds
# acc: 91.83 best_acc: 91.92
#
#
#
# Epoch 75 / 200: avg. loss of last 5 iterations 0.04068021150305867 , Time : 35.857048749923706 seconds
# acc: 92.19 best_acc: 91.92
# Saving..
#
#
#
# Epoch 76 / 200: avg. loss of last 5 iterations 0.01232464648783207 , Time : 35.861332178115845 seconds
# acc: 91.81 best_acc: 92.19
#
#
#
# Epoch 77 / 200: avg. loss of last 5 iterations 0.029945997055619955 , Time : 35.83647894859314 seconds
# acc: 91.58 best_acc: 92.19
#
#
#
# Epoch 78 / 200: avg. loss of last 5 iterations 0.01645474284887314 , Time : 35.83930730819702 seconds
# acc: 91.79 best_acc: 92.19
#
#
#
# Epoch 79 / 200: avg. loss of last 5 iterations 0.08786698170006275 , Time : 35.73182678222656 seconds
# acc: 92.08 best_acc: 92.19
#
#
#
# Epoch 80 / 200: avg. loss of last 5 iterations 0.02956249173730612 , Time : 35.81476092338562 seconds
# acc: 91.81 best_acc: 92.19
#
#
#
# Epoch 81 / 200: avg. loss of last 5 iterations 0.08383990535512567 , Time : 35.842989921569824 seconds
# acc: 92.03 best_acc: 92.19
#
#
#
# Epoch 82 / 200: avg. loss of last 5 iterations 0.01364445306826383 , Time : 35.69582509994507 seconds
# acc: 92.03 best_acc: 92.19
#
#
#
# Epoch 83 / 200: avg. loss of last 5 iterations 0.03996722623705864 , Time : 35.87261390686035 seconds
# acc: 92.0 best_acc: 92.19
#
#
#
# Epoch 84 / 200: avg. loss of last 5 iterations 0.008286769641563297 , Time : 35.91008996963501 seconds
# acc: 91.61 best_acc: 92.19
#
#
#
# Epoch 85 / 200: avg. loss of last 5 iterations 0.012425294611603022 , Time : 35.8041455745697 seconds
# acc: 91.69 best_acc: 92.19
#
#
#
# Epoch 86 / 200: avg. loss of last 5 iterations 0.003239078470505774 , Time : 35.85321116447449 seconds
# acc: 91.84 best_acc: 92.19
#
#
#
# Epoch 87 / 200: avg. loss of last 5 iterations 0.04592350702732802 , Time : 35.9085795879364 seconds
# acc: 91.81 best_acc: 92.19
#
#
#
# Epoch 88 / 200: avg. loss of last 5 iterations 0.04100072430446744 , Time : 35.67912578582764 seconds
# acc: 92.11 best_acc: 92.19
#
#
#
# Epoch 89 / 200: avg. loss of last 5 iterations 0.024773562094196677 , Time : 35.83591294288635 seconds
# acc: 91.82 best_acc: 92.19
#
#
#
# Epoch 90 / 200: avg. loss of last 5 iterations 0.017897395556792615 , Time : 35.80818271636963 seconds
# acc: 91.7 best_acc: 92.19
#
#
#
# Epoch 91 / 200: avg. loss of last 5 iterations 0.017171070678159595 , Time : 35.981205224990845 seconds
# acc: 91.66 best_acc: 92.19
#
#
#
# Epoch 92 / 200: avg. loss of last 5 iterations 0.04184078276157379 , Time : 35.72768020629883 seconds
# acc: 91.63 best_acc: 92.19
#
#
#
# Epoch 93 / 200: avg. loss of last 5 iterations 0.04881934309378266 , Time : 35.7980260848999 seconds
# acc: 91.74 best_acc: 92.19
#
#
#
# Epoch 94 / 200: avg. loss of last 5 iterations 0.02838571076281369 , Time : 35.81424403190613 seconds
# acc: 91.74 best_acc: 92.19
#
#
#
# Epoch 95 / 200: avg. loss of last 5 iterations 0.008220688719302417 , Time : 35.97456479072571 seconds
# acc: 91.74 best_acc: 92.19
#
#
#
# Epoch 96 / 200: avg. loss of last 5 iterations 0.045024756249040364 , Time : 35.75218915939331 seconds
# acc: 91.91 best_acc: 92.19
#
#
#
# Epoch 97 / 200: avg. loss of last 5 iterations 0.01965758977457881 , Time : 35.84060740470886 seconds
# acc: 91.75 best_acc: 92.19
#
#
#
# Epoch 98 / 200: avg. loss of last 5 iterations 0.02179351691156626 , Time : 35.801159143447876 seconds
# acc: 91.36 best_acc: 92.19
#
#
#
# Epoch 99 / 200: avg. loss of last 5 iterations 0.03887025527305923 , Time : 35.77592611312866 seconds
# acc: 91.53 best_acc: 92.19
#
#
#
# Epoch 100 / 200: avg. loss of last 5 iterations 0.014566076081246137 , Time : 35.89418816566467 seconds
# acc: 91.64 best_acc: 92.19
#
#
#
# Epoch 101 / 200: avg. loss of last 5 iterations 0.03606817805557512 , Time : 35.827110052108765 seconds
# acc: 91.71 best_acc: 92.19
#
#
#
# Epoch 102 / 200: avg. loss of last 5 iterations 0.03607149557210505 , Time : 35.801337003707886 seconds
# acc: 91.66 best_acc: 92.19
#
#
#
# Epoch 103 / 200: avg. loss of last 5 iterations 0.021077933069318534 , Time : 35.79259705543518 seconds
# acc: 91.93 best_acc: 92.19
#
#
#
# Epoch 104 / 200: avg. loss of last 5 iterations 0.004180582240223885 , Time : 35.82620668411255 seconds
# acc: 91.59 best_acc: 92.19
#
#
#
# Epoch 105 / 200: avg. loss of last 5 iterations 0.01859548632055521 , Time : 35.72821879386902 seconds
# acc: 91.14 best_acc: 92.19
#
#
#
# Epoch 106 / 200: avg. loss of last 5 iterations 0.017486090771853924 , Time : 35.93968343734741 seconds
# acc: 92.02 best_acc: 92.19
#
#
#
# Epoch 107 / 200: avg. loss of last 5 iterations 0.012384350015781819 , Time : 35.76575517654419 seconds
# acc: 91.39 best_acc: 92.19
#
#
#
# Epoch 108 / 200: avg. loss of last 5 iterations 0.03214545547962189 , Time : 35.898502588272095 seconds
# acc: 91.47 best_acc: 92.19
#
#
#
# Epoch 109 / 200: avg. loss of last 5 iterations 0.07088333582505583 , Time : 35.887428522109985 seconds
# acc: 91.34 best_acc: 92.19
#
#
#
# Epoch 110 / 200: avg. loss of last 5 iterations 0.007909641379956155 , Time : 35.837382793426514 seconds
# acc: 91.66 best_acc: 92.19
#
#
#
# Epoch 111 / 200: avg. loss of last 5 iterations 0.02320904395892285 , Time : 35.79086685180664 seconds
# acc: 91.09 best_acc: 92.19
#
#
#
# Epoch 112 / 200: avg. loss of last 5 iterations 0.021639436716213822 , Time : 35.82414960861206 seconds
# acc: 90.79 best_acc: 92.19
#
#
#
# Epoch 113 / 200: avg. loss of last 5 iterations 0.006860601389780641 , Time : 35.900734424591064 seconds
# acc: 91.24 best_acc: 92.19
#
#
#
# Epoch 114 / 200: avg. loss of last 5 iterations 0.004615047440165654 , Time : 35.97476553916931 seconds
# acc: 91.88 best_acc: 92.19
#
#
#
# Epoch 115 / 200: avg. loss of last 5 iterations 0.012631465145386756 , Time : 35.93994212150574 seconds
# acc: 91.39 best_acc: 92.19
#
#
#
# Epoch 116 / 200: avg. loss of last 5 iterations 0.025670488132163882 , Time : 35.85655212402344 seconds
# acc: 91.88 best_acc: 92.19
#
#
#
# Epoch 117 / 200: avg. loss of last 5 iterations 0.010640613199211658 , Time : 35.93167209625244 seconds
# acc: 91.66 best_acc: 92.19
#
#
#
# Epoch 118 / 200: avg. loss of last 5 iterations 0.008867013198323549 , Time : 35.84441661834717 seconds
# acc: 91.39 best_acc: 92.19
#
#
#
# Epoch 119 / 200: avg. loss of last 5 iterations 0.013438437043805606 , Time : 35.72221493721008 seconds
# acc: 91.29 best_acc: 92.19
#
#
#
# Epoch 120 / 200: avg. loss of last 5 iterations 0.03048001891002059 , Time : 35.83625078201294 seconds
# acc: 91.89 best_acc: 92.19
#
#
#
# Epoch 121 / 200: avg. loss of last 5 iterations 0.0075807131011970345 , Time : 35.77304553985596 seconds
# acc: 92.07 best_acc: 92.19
#
#
#
# Epoch 122 / 200: avg. loss of last 5 iterations 0.0033665321388980374 , Time : 35.80747318267822 seconds
# acc: 92.08 best_acc: 92.19
#
#
#
# Epoch 123 / 200: avg. loss of last 5 iterations 0.03553365494590253 , Time : 35.86353373527527 seconds
# acc: 92.14 best_acc: 92.19
#
#
#
# Epoch 124 / 200: avg. loss of last 5 iterations 0.010699224937707186 , Time : 35.859124422073364 seconds
# acc: 92.14 best_acc: 92.19
#
#
#
# Epoch 125 / 200: avg. loss of last 5 iterations 0.006498865503817797 , Time : 35.85331344604492 seconds
# acc: 92.08 best_acc: 92.19
#
#
#
# Epoch 126 / 200: avg. loss of last 5 iterations 0.002183675259584561 , Time : 35.83515191078186 seconds
# acc: 92.19 best_acc: 92.19
#
#
#
# Epoch 127 / 200: avg. loss of last 5 iterations 0.0069365476490929725 , Time : 35.74250864982605 seconds
# acc: 92.12 best_acc: 92.19
#
#
#
# Epoch 128 / 200: avg. loss of last 5 iterations 0.014273830712772906 , Time : 35.84516000747681 seconds
# acc: 92.25 best_acc: 92.19
# Saving..
#
#
#
# Epoch 129 / 200: avg. loss of last 5 iterations 0.00722195329144597 , Time : 35.83181691169739 seconds
# acc: 92.24 best_acc: 92.25
#
#
#
# Epoch 130 / 200: avg. loss of last 5 iterations 0.004239602155575994 , Time : 35.75233268737793 seconds
# acc: 92.24 best_acc: 92.25
#
#
#
# Epoch 131 / 200: avg. loss of last 5 iterations 0.002261569129768759 , Time : 35.880351305007935 seconds
# acc: 92.18 best_acc: 92.25
#
#
#
# Epoch 132 / 200: avg. loss of last 5 iterations 0.014788765995763242 , Time : 35.77331495285034 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 133 / 200: avg. loss of last 5 iterations 0.013389865891076625 , Time : 35.79320502281189 seconds
# acc: 92.1 best_acc: 92.25
#
#
#
# Epoch 134 / 200: avg. loss of last 5 iterations 0.005020489392336458 , Time : 35.74201512336731 seconds
# acc: 92.03 best_acc: 92.25
#
#
#
# Epoch 135 / 200: avg. loss of last 5 iterations 0.0016891185950953513 , Time : 35.89546537399292 seconds
# acc: 92.12 best_acc: 92.25
#
#
#
# Epoch 136 / 200: avg. loss of last 5 iterations 0.006989327511473675 , Time : 35.798662185668945 seconds
# acc: 92.14 best_acc: 92.25
#
#
#
# Epoch 137 / 200: avg. loss of last 5 iterations 0.00486285999068059 , Time : 35.87679862976074 seconds
# acc: 92.17 best_acc: 92.25
#
#
#
# Epoch 138 / 200: avg. loss of last 5 iterations 0.009058731963159516 , Time : 35.83665204048157 seconds
# acc: 92.07 best_acc: 92.25
#
#
#
# Epoch 139 / 200: avg. loss of last 5 iterations 0.0011228859395487234 , Time : 35.90477275848389 seconds
# acc: 92.23 best_acc: 92.25
#
#
#
# Epoch 140 / 200: avg. loss of last 5 iterations 0.0011841307685244828 , Time : 35.77283239364624 seconds
# acc: 92.24 best_acc: 92.25
#
#
#
# Epoch 141 / 200: avg. loss of last 5 iterations 0.02205273720319383 , Time : 35.784581661224365 seconds
# acc: 92.2 best_acc: 92.25
#
#
#
# Epoch 142 / 200: avg. loss of last 5 iterations 0.0041542175895301625 , Time : 35.947656869888306 seconds
# acc: 92.14 best_acc: 92.25
#
#
#
# Epoch 143 / 200: avg. loss of last 5 iterations 0.004487616603728384 , Time : 35.84124946594238 seconds
# acc: 92.15 best_acc: 92.25
#
#
#
# Epoch 144 / 200: avg. loss of last 5 iterations 0.015237520227674394 , Time : 35.82750678062439 seconds
# acc: 92.23 best_acc: 92.25
#
#
#
# Epoch 145 / 200: avg. loss of last 5 iterations 0.005217821389669553 , Time : 35.86005520820618 seconds
# acc: 92.13 best_acc: 92.25
#
#
#
# Epoch 146 / 200: avg. loss of last 5 iterations 0.0021135251750820316 , Time : 35.769848585128784 seconds
# acc: 92.08 best_acc: 92.25
#
#
#
# Epoch 147 / 200: avg. loss of last 5 iterations 0.0026271135131537447 , Time : 35.982691287994385 seconds
# acc: 92.07 best_acc: 92.25
#
#
#
# Epoch 148 / 200: avg. loss of last 5 iterations 0.003246534732170403 , Time : 35.89194178581238 seconds
# acc: 92.15 best_acc: 92.25
#
#
#
# Epoch 149 / 200: avg. loss of last 5 iterations 0.0015195913481875322 , Time : 35.733975887298584 seconds
# acc: 92.06 best_acc: 92.25
#
#
#
# Epoch 150 / 200: avg. loss of last 5 iterations 0.0030994324362836776 , Time : 35.90710520744324 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 151 / 200: avg. loss of last 5 iterations 0.004111439510597848 , Time : 35.873260259628296 seconds
# acc: 92.08 best_acc: 92.25
#
#
#
# Epoch 152 / 200: avg. loss of last 5 iterations 0.0016009769155061805 , Time : 35.792158126831055 seconds
# acc: 92.07 best_acc: 92.25
#
#
#
# Epoch 153 / 200: avg. loss of last 5 iterations 0.010260404320433736 , Time : 35.81712508201599 seconds
# acc: 92.05 best_acc: 92.25
#
#
#
# Epoch 154 / 200: avg. loss of last 5 iterations 0.0008397169236559421 , Time : 35.82312297821045 seconds
# acc: 92.06 best_acc: 92.25
#
#
#
# Epoch 155 / 200: avg. loss of last 5 iterations 0.005032039835350588 , Time : 35.70897388458252 seconds
# acc: 92.02 best_acc: 92.25
#
#
#
# Epoch 156 / 200: avg. loss of last 5 iterations 0.003325843543279916 , Time : 35.88015699386597 seconds
# acc: 92.02 best_acc: 92.25
#
#
#
# Epoch 157 / 200: avg. loss of last 5 iterations 0.0015523142064921558 , Time : 35.80116558074951 seconds
# acc: 92.12 best_acc: 92.25
#
#
#
# Epoch 158 / 200: avg. loss of last 5 iterations 0.0019228516786824912 , Time : 35.848899364471436 seconds
# acc: 92.03 best_acc: 92.25
#
#
#
# Epoch 159 / 200: avg. loss of last 5 iterations 0.0008761060249526054 , Time : 35.90447163581848 seconds
# acc: 92.14 best_acc: 92.25
#
#
#
# Epoch 160 / 200: avg. loss of last 5 iterations 0.0026400270318845285 , Time : 35.8179395198822 seconds
# acc: 92.17 best_acc: 92.25
#
#
#
# Epoch 161 / 200: avg. loss of last 5 iterations 0.0016864364239154383 , Time : 35.71419286727905 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 162 / 200: avg. loss of last 5 iterations 0.0046572253835620355 , Time : 35.871904373168945 seconds
# acc: 92.01 best_acc: 92.25
#
#
#
# Epoch 163 / 200: avg. loss of last 5 iterations 0.005559829108096892 , Time : 35.8265655040741 seconds
# acc: 91.99 best_acc: 92.25
#
#
#
# Epoch 164 / 200: avg. loss of last 5 iterations 0.01813921402208507 , Time : 35.839343547821045 seconds
# acc: 92.03 best_acc: 92.25
#
#
#
# Epoch 165 / 200: avg. loss of last 5 iterations 0.011779461917467416 , Time : 35.89995861053467 seconds
# acc: 92.02 best_acc: 92.25
#
#
#
# Epoch 166 / 200: avg. loss of last 5 iterations 0.012372395512647927 , Time : 35.804587602615356 seconds
# acc: 91.97 best_acc: 92.25
#
#
#
# Epoch 167 / 200: avg. loss of last 5 iterations 0.0030378978932276367 , Time : 35.91065788269043 seconds
# acc: 92.12 best_acc: 92.25
#
#
#
# Epoch 168 / 200: avg. loss of last 5 iterations 0.0010142843732865003 , Time : 35.780325174331665 seconds
# acc: 92.11 best_acc: 92.25
#
#
#
# Epoch 169 / 200: avg. loss of last 5 iterations 0.006614520849689142 , Time : 35.84088587760925 seconds
# acc: 92.08 best_acc: 92.25
#
#
#
# Epoch 170 / 200: avg. loss of last 5 iterations 0.0017895251818117685 , Time : 35.88202214241028 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 171 / 200: avg. loss of last 5 iterations 0.001247442464955384 , Time : 35.88451957702637 seconds
# acc: 92.14 best_acc: 92.25
#
#
#
# Epoch 172 / 200: avg. loss of last 5 iterations 0.00504231876693666 , Time : 35.79953193664551 seconds
# acc: 92.08 best_acc: 92.25
#
#
#
# Epoch 173 / 200: avg. loss of last 5 iterations 0.0009115392924286426 , Time : 35.8478684425354 seconds
# acc: 92.01 best_acc: 92.25
#
#
#
# Epoch 174 / 200: avg. loss of last 5 iterations 0.0014484297367744147 , Time : 35.714582443237305 seconds
# acc: 92.01 best_acc: 92.25
#
#
#
# Epoch 175 / 200: avg. loss of last 5 iterations 0.0038369525689631702 , Time : 35.93016505241394 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 176 / 200: avg. loss of last 5 iterations 0.004319209148525261 , Time : 35.867830753326416 seconds
# acc: 92.13 best_acc: 92.25
#
#
#
# Epoch 177 / 200: avg. loss of last 5 iterations 0.0007152475358452648 , Time : 35.92493152618408 seconds
# acc: 92.0 best_acc: 92.25
#
#
#
# Epoch 178 / 200: avg. loss of last 5 iterations 0.027696234481118152 , Time : 35.81196475028992 seconds
# acc: 92.2 best_acc: 92.25
#
#
#
# Epoch 179 / 200: avg. loss of last 5 iterations 0.0012563747062813491 , Time : 35.85437750816345 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 180 / 200: avg. loss of last 5 iterations 0.0029567389632575215 , Time : 35.78749680519104 seconds
# acc: 92.04 best_acc: 92.25
#
#
#
# Epoch 181 / 200: avg. loss of last 5 iterations 0.008631326723843813 , Time : 35.82031464576721 seconds
# acc: 92.08 best_acc: 92.25
#
#
#
# Epoch 182 / 200: avg. loss of last 5 iterations 0.0019987122796010226 , Time : 35.84580969810486 seconds
# acc: 92.01 best_acc: 92.25
#
#
#
# Epoch 183 / 200: avg. loss of last 5 iterations 0.0018031474348390475 , Time : 35.807080030441284 seconds
# acc: 92.05 best_acc: 92.25
#
#
#
# Epoch 184 / 200: avg. loss of last 5 iterations 0.003584275644971058 , Time : 35.861255407333374 seconds
# acc: 92.07 best_acc: 92.25
#
#
#
# Epoch 185 / 200: avg. loss of last 5 iterations 0.0007840697711799294 , Time : 35.89366412162781 seconds
# acc: 92.06 best_acc: 92.25
#
#
#
# Epoch 186 / 200: avg. loss of last 5 iterations 0.00111639586975798 , Time : 35.754764556884766 seconds
# acc: 92.07 best_acc: 92.25
#
#
#
# Epoch 187 / 200: avg. loss of last 5 iterations 0.0011918879783479497 , Time : 35.91665554046631 seconds
# acc: 92.06 best_acc: 92.25
#
#
#
# Epoch 188 / 200: avg. loss of last 5 iterations 0.0007851367583498359 , Time : 35.81323432922363 seconds
# acc: 92.11 best_acc: 92.25
#
#
#
# Epoch 189 / 200: avg. loss of last 5 iterations 0.0007130398182198406 , Time : 35.90465593338013 seconds
# acc: 92.1 best_acc: 92.25
#
#
#
# Epoch 190 / 200: avg. loss of last 5 iterations 0.0015824726200662554 , Time : 35.88884663581848 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 191 / 200: avg. loss of last 5 iterations 0.0026088318263646215 , Time : 35.72756624221802 seconds
# acc: 92.09 best_acc: 92.25
#
#
#
# Epoch 192 / 200: avg. loss of last 5 iterations 0.0013284909982758109 , Time : 35.96697664260864 seconds
# acc: 92.15 best_acc: 92.25
#
#
#
# Epoch 193 / 200: avg. loss of last 5 iterations 0.001964122976642102 , Time : 35.74927854537964 seconds
# acc: 92.14 best_acc: 92.25
#
#
#
# Epoch 194 / 200: avg. loss of last 5 iterations 0.0005074895161669701 , Time : 35.976733446121216 seconds
# acc: 92.08 best_acc: 92.25
#
#
#
# Epoch 195 / 200: avg. loss of last 5 iterations 0.0010193995345616712 , Time : 35.78296160697937 seconds
# acc: 92.18 best_acc: 92.25
#
#
#
# Epoch 196 / 200: avg. loss of last 5 iterations 0.0013301565340952948 , Time : 35.80920100212097 seconds
# acc: 92.11 best_acc: 92.25
#
#
#
# Epoch 197 / 200: avg. loss of last 5 iterations 0.0025097299221670255 , Time : 35.85292363166809 seconds
# acc: 92.1 best_acc: 92.25
#
#
#
# Epoch 198 / 200: avg. loss of last 5 iterations 0.005003102196496911 , Time : 35.87925148010254 seconds
# acc: 92.15 best_acc: 92.25
#
#
#
# Epoch 199 / 200: avg. loss of last 5 iterations 0.002282230013224762 , Time : 35.81599831581116 seconds
# acc: 92.19 best_acc: 92.25
#
#
#
# Epoch 200 / 200: avg. loss of last 5 iterations 0.001401232496573357 , Time : 35.87619137763977 seconds
# acc: 92.22 best_acc: 92.25

# %% [markdown]
# ### 4.3 The Loss Curve
# Loss curve is visualized.

# %%
plt.plot(loss_history)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# ### 4.4 Quantitative Analysis
#
# We can analyze the accuracy of the predictions as follows.

# %%
correct = 0
total = 0
with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(testloader):
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = net(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 92 %

# %%
print('saving' ,'acc:',best_acc)
# Out:
# saving acc: 92.25

# %% [markdown]
# ### 5 Results
#
# Accuracy vs epoch is plotted according to the test results.

# %%
plt.plot(historyy)
plt.xlabel('Epoch number')
plt.ylabel('Accuracy')
plt.show()
print(historyy)
# Out:
# [41.62, 54.17, 59.74, 63.16, 69.06, 73.02, 76.6, 78.52, 78.05, 79.42, 78.65, 79.85, 79.9, 84.67, 83.1, 83.06, 83.62, 83.37, 84.68, 85.75, 85.44, 84.71, 85.08, 86.4, 86.47, 86.23, 84.3, 85.84, 85.96, 86.91, 85.56, 87.24, 86.79, 86.44, 84.73, 86.12, 86.96, 86.5, 86.8, 86.7, 86.49, 87.41, 88.17, 86.93, 87.41, 86.05, 86.89, 87.16, 87.68, 84.86, 88.03, 85.17, 88.05, 86.67, 88.74, 88.52, 86.05, 88.96, 88.46, 88.8, 91.37, 91.45, 91.7, 91.65, 91.69, 91.89, 91.88, 91.68, 91.64, 91.92, 91.86, 91.53, 91.83, 91.83, 92.19, 91.81, 91.58, 91.79, 92.08, 91.81, 92.03, 92.03, 92.0, 91.61, 91.69, 91.84, 91.81, 92.11, 91.82, 91.7, 91.66, 91.63, 91.74, 91.74, 91.74, 91.91, 91.75, 91.36, 91.53, 91.64, 91.71, 91.66, 91.93, 91.59, 91.14, 92.02, 91.39, 91.47, 91.34, 91.66, 91.09, 90.79, 91.24, 91.88, 91.39, 91.88, 91.66, 91.39, 91.29, 91.89, 92.07, 92.08, 92.14, 92.14, 92.08, 92.19, 92.12, 92.25, 92.24, 92.24, 92.18, 92.09, 92.1, 92.03, 92.12, 92.14, 92.17, 92.07, 92.23, 92.24, 92.2, 92.14, 92.15, 92.23, 92.13, 92.08, 92.07, 92.15, 92.06, 92.09, 92.08, 92.07, 92.05, 92.06, 92.02, 92.02, 92.12, 92.03, 92.14, 92.17, 92.09, 92.01, 91.99, 92.03, 92.02, 91.97, 92.12, 92.11, 92.08, 92.09, 92.14, 92.08, 92.01, 92.01, 92.09, 92.13, 92.0, 92.2, 92.09, 92.04, 92.08, 92.01, 92.05, 92.07, 92.06, 92.07, 92.06, 92.11, 92.1, 92.09, 92.09, 92.15, 92.14, 92.08, 92.18, 92.11, 92.1, 92.15, 92.19, 92.22]
