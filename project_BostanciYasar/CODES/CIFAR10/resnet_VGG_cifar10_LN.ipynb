# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
import torchvision.transforms as transforms
import sys

import matplotlib.pyplot as plt 
import time   

import os
import argparse

# %% [markdown]
# ### 1.1 Enable GPU
#
# From "Edit -> Notebook Settings -> Hardware accelerator" select GPU. With the following we will specify to PyTorch that we want to use the GPU.

# %%
if torch.cuda.is_available():
  print("Cuda (GPU support) is available and enabled!")
  device = torch.device("cuda")
else:
  print("Cuda (GPU support) is not available :(")
  device = torch.device("cpu")
# Out:
# Cuda (GPU support) is available and enabled!

# %% [markdown]
# ### 2 Model Definition
#
#
# In the original paper there are two different frameworks; ResNet and VGG. In this section, different models for different frameworks are created. However, in the original paper different normalization methods are applied in these frameworks and as mentioned the authors of the paper propose a new method which is called momentum Batch Normalization. In ResNet and VGG frameworks a naive batch normalization block is used and modified according to the proposed Momentum Batch Normalization method. On the other hand, Pytorch functions are used directly for other normalization methods such as Group Normalization, Layer Normalization, Instance Normalization and Batch Normalization for ResNet.

# %% [markdown]
# ### 2.1 ResNet
#
# ResNet18, ResNet34 and ResNet50 architectures are defined according to the original paper as folllows.

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.GroupNorm(1, planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.GroupNorm(1, planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.GroupNorm(1, self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(1, planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.GroupNorm(1, planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(1, self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.GroupNorm(1, self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.GroupNorm(1, 64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

# %% [markdown]
# ### 2.2 VGG
#
# VGG11 and VGG16 architectures are defined according to the original paper as folllows.

# %%
configuration = {
    'VGG11': [64, 'pool', 128, 'pool', 256, 256, 'pool', 512, 512, 'pool', 512, 512, 'pool'],
    'VGG16': [64, 64, 'pool', 128, 128, 'pool', 256, 256, 256, 'pool', 512, 512, 512, 'pool', 512, 512, 512, 'pool']
}


class VGG(nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(configuration[vgg_name])
        self.classifier = nn.Linear(512, 100)

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

    def _make_layers(self, configuration):
        layers = []
        in_channels = 3
        for x in configuration:
            if x == 'pool':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)

# %% [markdown]
# ## 3 The Dataset
#
# In the original paper authors used CIFAR10 and CIFAR100 datasets. In this section torchvision function is used to load train/test datasets;
#
# *   There are 50000 training images and 10000 test images for  10 different classes for CIFAR10
# *   There are 50000 training images and 10000 test images for 100 different classes for CIFAR100.
#
# In the original paper, authors mentions standard data augmentation and preprocessing techniques are used but any specific parameters were not given in the paper or in the supplementary material of the paper. Therefore, data augmentation and preprocessing techniques are taken from the literature and applied to the datasets.

# %%
# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize((0, 0, 0), (1, 1, 1)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0, 0, 0), (1, 1, 1)),
])

###################
batch_size=32 #batch size (2 per gpu)
m0=32 #ideal batch size
######################


trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2) # 4 gpu

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# ==> Preparing data..
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### 4 Define and Train Model
# In this section user can choose the model between the ResNet18, ResNet34, ResNet50, VGG11 and VGG16 frameworks.

# %% [markdown]
# ### 4.1 Define Loss Function and the Optimizer
#
# Instance is created for the model based on the choice.
#
# In the original paper authors used Stochastic Gradient Descent for the optimization with the momentum 0.9 and weight decay 0.0001 paramaeters set. In the experiments these parameters and optimization method from the paper are preserved.
#
# Since the criterion for the loss function is not specified exactly in the original paper Cross-Entropy Loss method is chosen in the experiments.

# %%
sys.argv=['']
del sys


best_acc = 0  # best test accuracy
start_epoch = 1  


# Model
print('==> Building model..')

#net = VGG('VGG11')
# net = VGG('VGG16')
net = ResNet18()
# net = ResNet34()
# net = ResNet50()

net = net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.1*batch_size/64,
                      momentum=0.9, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 180], gamma=0.1)
# Out:
# ==> Building model..

# %% [markdown]
# ### 4.2 Train the Model
#
# In the original paper, authors propose a new method in order to train large datasets with small batch-sizes for insufficient memory resources. Therefore, in the experiments considerably smaller batch sizes are used and it extends the training times. In order to overcome high training times problem GPU usage becomes a necessity and cuda is used in the experiments with Colab Pro.

# %%
# Training and Accuracy Calculation
def train(verbose=True):
    
    loss_history=[]
    net.train()
    correct = 0
    total = 0
    for epoch in range(start_epoch, start_epoch+epoch_number):
      
      start = time.time()
      for batch_idx, (inputs, targets) in enumerate(trainloader):
          inputs, targets = inputs.to(device), targets.to(device)
          
          optimizer.zero_grad()
          outputs = net(inputs)
          loss = criterion(outputs, targets)
          loss.backward()
          optimizer.step()


          loss_history.append(loss.item()) 

      end = time.time()
      if verbose: print(f'Epoch {epoch} / {epoch_number}: avg. loss of last 5 iterations {np.sum(loss_history[:-6:-1])/5} , Time : {end - start} seconds')            

      global best_acc
      global test_loss
      net.eval()
      test_loss = 0
      correct = 0
      total = 0
      with torch.no_grad():
          for batch_idx, (inputs, targets) in enumerate(testloader):
              inputs, targets = inputs.to(device), targets.to(device)
              outputs = net(inputs)  
              _, predicted = outputs.max(1)
              total += targets.size(0)
              correct += predicted.eq(targets).sum().item()       


      acc = 100.*correct/total
      historyy.append(acc)

      print('acc:',acc,'best_acc:',best_acc)
      if acc > best_acc:
          print('Saving..' )
          
          state = {
              'net': net.state_dict(),
              'acc': acc,
              'epoch': epoch,
          }
          best_acc = acc
          
      print('\n\n') 
      scheduler.step() 
    return loss_history

# %%
epoch_number=200
historyy=[]
losses=[]


loss_history=train()
# Out:
# Epoch 1 / 200: avg. loss of last 5 iterations 1.843379306793213 , Time : 38.97850513458252 seconds
# acc: 28.27 best_acc: 0
# Saving..
#
#
#
# Epoch 2 / 200: avg. loss of last 5 iterations 1.719175386428833 , Time : 38.82243585586548 seconds
# acc: 38.74 best_acc: 28.27
# Saving..
#
#
#
# Epoch 3 / 200: avg. loss of last 5 iterations 1.6368913412094117 , Time : 38.70823693275452 seconds
# acc: 44.89 best_acc: 38.74
# Saving..
#
#
#
# Epoch 4 / 200: avg. loss of last 5 iterations 1.349320149421692 , Time : 38.71090650558472 seconds
# acc: 47.36 best_acc: 44.89
# Saving..
#
#
#
# Epoch 5 / 200: avg. loss of last 5 iterations 1.349562644958496 , Time : 38.775814056396484 seconds
# acc: 51.94 best_acc: 47.36
# Saving..
#
#
#
# Epoch 6 / 200: avg. loss of last 5 iterations 1.092560601234436 , Time : 38.76001811027527 seconds
# acc: 59.5 best_acc: 51.94
# Saving..
#
#
#
# Epoch 7 / 200: avg. loss of last 5 iterations 0.868468165397644 , Time : 38.81758403778076 seconds
# acc: 57.87 best_acc: 59.5
#
#
#
# Epoch 8 / 200: avg. loss of last 5 iterations 1.0705334186553954 , Time : 38.943089962005615 seconds
# acc: 68.63 best_acc: 59.5
# Saving..
#
#
#
# Epoch 9 / 200: avg. loss of last 5 iterations 0.9516103625297546 , Time : 38.83044385910034 seconds
# acc: 70.4 best_acc: 68.63
# Saving..
#
#
#
# Epoch 10 / 200: avg. loss of last 5 iterations 1.0552995920181274 , Time : 38.754011392593384 seconds
# acc: 74.33 best_acc: 70.4
# Saving..
#
#
#
# Epoch 11 / 200: avg. loss of last 5 iterations 0.6778999388217926 , Time : 38.74550533294678 seconds
# acc: 75.67 best_acc: 74.33
# Saving..
#
#
#
# Epoch 12 / 200: avg. loss of last 5 iterations 0.6538592636585235 , Time : 38.836780309677124 seconds
# acc: 76.4 best_acc: 75.67
# Saving..
#
#
#
# Epoch 13 / 200: avg. loss of last 5 iterations 0.5642473995685577 , Time : 38.619060754776 seconds
# acc: 75.11 best_acc: 76.4
#
#
#
# Epoch 14 / 200: avg. loss of last 5 iterations 0.6932796597480774 , Time : 38.78053426742554 seconds
# acc: 77.82 best_acc: 76.4
# Saving..
#
#
#
# Epoch 15 / 200: avg. loss of last 5 iterations 0.5265128314495087 , Time : 38.777979373931885 seconds
# acc: 78.5 best_acc: 77.82
# Saving..
#
#
#
# Epoch 16 / 200: avg. loss of last 5 iterations 0.5357879936695099 , Time : 38.79422569274902 seconds
# acc: 81.87 best_acc: 78.5
# Saving..
#
#
#
# Epoch 17 / 200: avg. loss of last 5 iterations 0.48855419754981994 , Time : 38.72488451004028 seconds
# acc: 80.77 best_acc: 81.87
#
#
#
# Epoch 18 / 200: avg. loss of last 5 iterations 0.6742583632469177 , Time : 38.852416038513184 seconds
# acc: 81.96 best_acc: 81.87
# Saving..
#
#
#
# Epoch 19 / 200: avg. loss of last 5 iterations 0.4934036910533905 , Time : 38.71351742744446 seconds
# acc: 81.46 best_acc: 81.96
#
#
#
# Epoch 20 / 200: avg. loss of last 5 iterations 0.5838809430599212 , Time : 38.67381501197815 seconds
# acc: 81.17 best_acc: 81.96
#
#
#
# Epoch 21 / 200: avg. loss of last 5 iterations 0.305189049243927 , Time : 38.81513977050781 seconds
# acc: 83.36 best_acc: 81.96
# Saving..
#
#
#
# Epoch 22 / 200: avg. loss of last 5 iterations 0.35347056686878203 , Time : 38.68234181404114 seconds
# acc: 83.48 best_acc: 83.36
# Saving..
#
#
#
# Epoch 23 / 200: avg. loss of last 5 iterations 0.46886528432369234 , Time : 38.72928214073181 seconds
# acc: 83.75 best_acc: 83.48
# Saving..
#
#
#
# Epoch 24 / 200: avg. loss of last 5 iterations 0.5175777941942215 , Time : 38.82065510749817 seconds
# acc: 82.83 best_acc: 83.75
#
#
#
# Epoch 25 / 200: avg. loss of last 5 iterations 0.4636505365371704 , Time : 38.698888063430786 seconds
# acc: 85.0 best_acc: 83.75
# Saving..
#
#
#
# Epoch 26 / 200: avg. loss of last 5 iterations 0.45933137834072113 , Time : 38.64176368713379 seconds
# acc: 83.03 best_acc: 85.0
#
#
#
# Epoch 27 / 200: avg. loss of last 5 iterations 0.3557816118001938 , Time : 38.69846224784851 seconds
# acc: 86.05 best_acc: 85.0
# Saving..
#
#
#
# Epoch 28 / 200: avg. loss of last 5 iterations 0.2788355588912964 , Time : 38.836079359054565 seconds
# acc: 84.77 best_acc: 86.05
#
#
#
# Epoch 29 / 200: avg. loss of last 5 iterations 0.32504819631576537 , Time : 38.74718618392944 seconds
# acc: 85.54 best_acc: 86.05
#
#
#
# Epoch 30 / 200: avg. loss of last 5 iterations 0.3194502204656601 , Time : 38.65610146522522 seconds
# acc: 82.85 best_acc: 86.05
#
#
#
# Epoch 31 / 200: avg. loss of last 5 iterations 0.3755149781703949 , Time : 38.814249992370605 seconds
# acc: 84.78 best_acc: 86.05
#
#
#
# Epoch 32 / 200: avg. loss of last 5 iterations 0.4651134669780731 , Time : 38.773176431655884 seconds
# acc: 84.32 best_acc: 86.05
#
#
#
# Epoch 33 / 200: avg. loss of last 5 iterations 0.31611184775829315 , Time : 38.63076710700989 seconds
# acc: 84.84 best_acc: 86.05
#
#
#
# Epoch 34 / 200: avg. loss of last 5 iterations 0.5290045320987702 , Time : 38.64380979537964 seconds
# acc: 85.32 best_acc: 86.05
#
#
#
# Epoch 35 / 200: avg. loss of last 5 iterations 0.4100818455219269 , Time : 38.78651738166809 seconds
# acc: 86.36 best_acc: 86.05
# Saving..
#
#
#
# Epoch 36 / 200: avg. loss of last 5 iterations 0.27763708531856535 , Time : 38.827131032943726 seconds
# acc: 84.24 best_acc: 86.36
#
#
#
# Epoch 37 / 200: avg. loss of last 5 iterations 0.36309889554977415 , Time : 38.726462602615356 seconds
# acc: 85.79 best_acc: 86.36
#
#
#
# Epoch 38 / 200: avg. loss of last 5 iterations 0.5161074936389923 , Time : 38.79826593399048 seconds
# acc: 84.72 best_acc: 86.36
#
#
#
# Epoch 39 / 200: avg. loss of last 5 iterations 0.32187493443489074 , Time : 38.61309027671814 seconds
# acc: 85.2 best_acc: 86.36
#
#
#
# Epoch 40 / 200: avg. loss of last 5 iterations 0.39747602939605714 , Time : 38.87281537055969 seconds
# acc: 85.9 best_acc: 86.36
#
#
#
# Epoch 41 / 200: avg. loss of last 5 iterations 0.380242520570755 , Time : 38.8832950592041 seconds
# acc: 85.19 best_acc: 86.36
#
#
#
# Epoch 42 / 200: avg. loss of last 5 iterations 0.23955478370189667 , Time : 38.76984190940857 seconds
# acc: 84.51 best_acc: 86.36
#
#
#
# Epoch 43 / 200: avg. loss of last 5 iterations 0.2611106723546982 , Time : 38.627450466156006 seconds
# acc: 86.18 best_acc: 86.36
#
#
#
# Epoch 44 / 200: avg. loss of last 5 iterations 0.3734436571598053 , Time : 38.822192668914795 seconds
# acc: 85.49 best_acc: 86.36
#
#
#
# Epoch 45 / 200: avg. loss of last 5 iterations 0.27374363839626314 , Time : 38.68632245063782 seconds
# acc: 87.46 best_acc: 86.36
# Saving..
#
#
#
# Epoch 46 / 200: avg. loss of last 5 iterations 0.4102400153875351 , Time : 38.61624836921692 seconds
# acc: 83.72 best_acc: 87.46
#
#
#
# Epoch 47 / 200: avg. loss of last 5 iterations 0.3708880513906479 , Time : 38.712390422821045 seconds
# acc: 85.41 best_acc: 87.46
#
#
#
# Epoch 48 / 200: avg. loss of last 5 iterations 0.24688328802585602 , Time : 38.74548959732056 seconds
# acc: 86.89 best_acc: 87.46
#
#
#
# Epoch 49 / 200: avg. loss of last 5 iterations 0.29309269040822983 , Time : 38.700660705566406 seconds
# acc: 87.02 best_acc: 87.46
#
#
#
# Epoch 50 / 200: avg. loss of last 5 iterations 0.28334538638591766 , Time : 38.67222356796265 seconds
# acc: 85.41 best_acc: 87.46
#
#
#
# Epoch 51 / 200: avg. loss of last 5 iterations 0.43842441141605376 , Time : 38.80909514427185 seconds
# acc: 86.4 best_acc: 87.46
#
#
#
# Epoch 52 / 200: avg. loss of last 5 iterations 0.45574733018875124 , Time : 38.707305669784546 seconds
# acc: 86.71 best_acc: 87.46
#
#
#
# Epoch 53 / 200: avg. loss of last 5 iterations 0.3113061338663101 , Time : 38.64308524131775 seconds
# acc: 87.27 best_acc: 87.46
#
#
#
# Epoch 54 / 200: avg. loss of last 5 iterations 0.26597591638565066 , Time : 38.777562379837036 seconds
# acc: 86.23 best_acc: 87.46
#
#
#
# Epoch 55 / 200: avg. loss of last 5 iterations 0.26717287600040435 , Time : 38.62119698524475 seconds
# acc: 87.56 best_acc: 87.46
# Saving..
#
#
#
# Epoch 56 / 200: avg. loss of last 5 iterations 0.30501142144203186 , Time : 38.68153715133667 seconds
# acc: 83.48 best_acc: 87.56
#
#
#
# Epoch 57 / 200: avg. loss of last 5 iterations 0.2901668295264244 , Time : 38.606223583221436 seconds
# acc: 84.41 best_acc: 87.56
#
#
#
# Epoch 58 / 200: avg. loss of last 5 iterations 0.26919638365507126 , Time : 38.77631115913391 seconds
# acc: 88.7 best_acc: 87.56
# Saving..
#
#
#
# Epoch 59 / 200: avg. loss of last 5 iterations 0.2184670776128769 , Time : 38.63232469558716 seconds
# acc: 85.72 best_acc: 88.7
#
#
#
# Epoch 60 / 200: avg. loss of last 5 iterations 0.2966059774160385 , Time : 38.8251051902771 seconds
# acc: 87.85 best_acc: 88.7
#
#
#
# Epoch 61 / 200: avg. loss of last 5 iterations 0.07878577411174774 , Time : 38.68574666976929 seconds
# acc: 91.33 best_acc: 88.7
# Saving..
#
#
#
# Epoch 62 / 200: avg. loss of last 5 iterations 0.09672299921512603 , Time : 38.68086910247803 seconds
# acc: 91.63 best_acc: 91.33
# Saving..
#
#
#
# Epoch 63 / 200: avg. loss of last 5 iterations 0.0770595096051693 , Time : 38.75561785697937 seconds
# acc: 91.53 best_acc: 91.63
#
#
#
# Epoch 64 / 200: avg. loss of last 5 iterations 0.10651162117719651 , Time : 38.77277398109436 seconds
# acc: 91.96 best_acc: 91.63
# Saving..
#
#
#
# Epoch 65 / 200: avg. loss of last 5 iterations 0.09741104915738105 , Time : 38.70047879219055 seconds
# acc: 91.78 best_acc: 91.96
#
#
#
# Epoch 66 / 200: avg. loss of last 5 iterations 0.1269718890544027 , Time : 38.58311486244202 seconds
# acc: 91.97 best_acc: 91.96
# Saving..
#
#
#
# Epoch 67 / 200: avg. loss of last 5 iterations 0.04411919673439115 , Time : 38.818920373916626 seconds
# acc: 92.11 best_acc: 91.97
# Saving..
#
#
#
# Epoch 68 / 200: avg. loss of last 5 iterations 0.1394600488245487 , Time : 38.6327691078186 seconds
# acc: 91.98 best_acc: 92.11
#
#
#
# Epoch 69 / 200: avg. loss of last 5 iterations 0.07722241636365652 , Time : 38.705716133117676 seconds
# acc: 92.18 best_acc: 92.11
# Saving..
#
#
#
# Epoch 70 / 200: avg. loss of last 5 iterations 0.03339673689333722 , Time : 38.481440782547 seconds
# acc: 92.27 best_acc: 92.18
# Saving..
#
#
#
# Epoch 71 / 200: avg. loss of last 5 iterations 0.11894765533506871 , Time : 38.48738646507263 seconds
# acc: 91.81 best_acc: 92.27
#
#
#
# Epoch 72 / 200: avg. loss of last 5 iterations 0.05927988495677709 , Time : 38.3674418926239 seconds
# acc: 92.11 best_acc: 92.27
#
#
#
# Epoch 73 / 200: avg. loss of last 5 iterations 0.04237610320560634 , Time : 38.47339677810669 seconds
# acc: 92.46 best_acc: 92.27
# Saving..
#
#
#
# Epoch 74 / 200: avg. loss of last 5 iterations 0.08098930027335882 , Time : 38.74927592277527 seconds
# acc: 92.31 best_acc: 92.46
#
#
#
# Epoch 75 / 200: avg. loss of last 5 iterations 0.06704265871085227 , Time : 38.665971755981445 seconds
# acc: 92.09 best_acc: 92.46
#
#
#
# Epoch 76 / 200: avg. loss of last 5 iterations 0.05154844559729099 , Time : 38.75024199485779 seconds
# acc: 92.28 best_acc: 92.46
#
#
#
# Epoch 77 / 200: avg. loss of last 5 iterations 0.058213806990534064 , Time : 38.801793336868286 seconds
# acc: 92.09 best_acc: 92.46
#
#
#
# Epoch 78 / 200: avg. loss of last 5 iterations 0.050730997882783416 , Time : 38.69843792915344 seconds
# acc: 92.01 best_acc: 92.46
#
#
#
# Epoch 79 / 200: avg. loss of last 5 iterations 0.0410400471650064 , Time : 38.85163998603821 seconds
# acc: 92.02 best_acc: 92.46
#
#
#
# Epoch 80 / 200: avg. loss of last 5 iterations 0.01744478465989232 , Time : 38.716217279434204 seconds
# acc: 92.05 best_acc: 92.46
#
#
#
# Epoch 81 / 200: avg. loss of last 5 iterations 0.03730875458568335 , Time : 38.79583930969238 seconds
# acc: 92.29 best_acc: 92.46
#
#
#
# Epoch 82 / 200: avg. loss of last 5 iterations 0.019708506704773754 , Time : 38.69155216217041 seconds
# acc: 92.25 best_acc: 92.46
#
#
#
# Epoch 83 / 200: avg. loss of last 5 iterations 0.01952513525611721 , Time : 38.73457384109497 seconds
# acc: 92.27 best_acc: 92.46
#
#
#
# Epoch 84 / 200: avg. loss of last 5 iterations 0.051902356930077075 , Time : 38.766475439071655 seconds
# acc: 91.83 best_acc: 92.46
#
#
#
# Epoch 85 / 200: avg. loss of last 5 iterations 0.035537313343957065 , Time : 38.69501805305481 seconds
# acc: 92.04 best_acc: 92.46
#
#
#
# Epoch 86 / 200: avg. loss of last 5 iterations 0.04917178261093795 , Time : 38.76829147338867 seconds
# acc: 91.77 best_acc: 92.46
#
#
#
# Epoch 87 / 200: avg. loss of last 5 iterations 0.022462357103358956 , Time : 38.889503955841064 seconds
# acc: 92.02 best_acc: 92.46
#
#
#
# Epoch 88 / 200: avg. loss of last 5 iterations 0.026205519307404758 , Time : 38.6777765750885 seconds
# acc: 92.32 best_acc: 92.46
#
#
#
# Epoch 89 / 200: avg. loss of last 5 iterations 0.058439052663743496 , Time : 38.668094873428345 seconds
# acc: 92.26 best_acc: 92.46
#
#
#
# Epoch 90 / 200: avg. loss of last 5 iterations 0.019109344040043653 , Time : 38.82458305358887 seconds
# acc: 91.94 best_acc: 92.46
#
#
#
# Epoch 91 / 200: avg. loss of last 5 iterations 0.043452201248146596 , Time : 38.69255828857422 seconds
# acc: 92.24 best_acc: 92.46
#
#
#
# Epoch 92 / 200: avg. loss of last 5 iterations 0.026189553458243607 , Time : 38.73287487030029 seconds
# acc: 92.21 best_acc: 92.46
#
#
#
# Epoch 93 / 200: avg. loss of last 5 iterations 0.0977797968313098 , Time : 38.78889870643616 seconds
# acc: 91.83 best_acc: 92.46
#
#
#
# Epoch 94 / 200: avg. loss of last 5 iterations 0.006703292531892657 , Time : 38.67599034309387 seconds
# acc: 92.48 best_acc: 92.46
# Saving..
#
#
#
# Epoch 95 / 200: avg. loss of last 5 iterations 0.003169412020361051 , Time : 38.836984395980835 seconds
# acc: 92.15 best_acc: 92.48
#
#
#
# Epoch 96 / 200: avg. loss of last 5 iterations 0.05214134334819391 , Time : 38.73509669303894 seconds
# acc: 91.98 best_acc: 92.48
#
#
#
# Epoch 97 / 200: avg. loss of last 5 iterations 0.027189763728529215 , Time : 38.791581869125366 seconds
# acc: 92.17 best_acc: 92.48
#
#
#
# Epoch 98 / 200: avg. loss of last 5 iterations 0.01793418505694717 , Time : 38.88920283317566 seconds
# acc: 91.87 best_acc: 92.48
#
#
#
# Epoch 99 / 200: avg. loss of last 5 iterations 0.01525899547850713 , Time : 38.69543433189392 seconds
# acc: 91.72 best_acc: 92.48
#
#
#
# Epoch 100 / 200: avg. loss of last 5 iterations 0.03258235901594162 , Time : 38.7431435585022 seconds
# acc: 92.03 best_acc: 92.48
#
#
#
# Epoch 101 / 200: avg. loss of last 5 iterations 0.036119023151695726 , Time : 38.74230170249939 seconds
# acc: 91.69 best_acc: 92.48
#
#
#
# Epoch 102 / 200: avg. loss of last 5 iterations 0.05863192870747298 , Time : 38.75464916229248 seconds
# acc: 91.92 best_acc: 92.48
#
#
#
# Epoch 103 / 200: avg. loss of last 5 iterations 0.0035134567879140377 , Time : 38.731168270111084 seconds
# acc: 91.93 best_acc: 92.48
#
#
#
# Epoch 104 / 200: avg. loss of last 5 iterations 0.055973907245788726 , Time : 38.73644399642944 seconds
# acc: 92.08 best_acc: 92.48
#
#
#
# Epoch 105 / 200: avg. loss of last 5 iterations 0.05399379376322031 , Time : 38.646533250808716 seconds
# acc: 91.16 best_acc: 92.48
#
#
#
# Epoch 106 / 200: avg. loss of last 5 iterations 0.03723234897479415 , Time : 38.763405561447144 seconds
# acc: 91.88 best_acc: 92.48
#
#
#
# Epoch 107 / 200: avg. loss of last 5 iterations 0.02930141785182059 , Time : 38.69768977165222 seconds
# acc: 91.9 best_acc: 92.48
#
#
#
# Epoch 108 / 200: avg. loss of last 5 iterations 0.03460960341617465 , Time : 38.84847903251648 seconds
# acc: 91.56 best_acc: 92.48
#
#
#
# Epoch 109 / 200: avg. loss of last 5 iterations 0.019977291487157343 , Time : 38.91726064682007 seconds
# acc: 92.0 best_acc: 92.48
#
#
#
# Epoch 110 / 200: avg. loss of last 5 iterations 0.012686807895079255 , Time : 38.74249815940857 seconds
# acc: 91.78 best_acc: 92.48
#
#
#
# Epoch 111 / 200: avg. loss of last 5 iterations 0.030694603733718396 , Time : 38.91968083381653 seconds
# acc: 90.81 best_acc: 92.48
#
#
#
# Epoch 112 / 200: avg. loss of last 5 iterations 0.03208859232254326 , Time : 38.83647847175598 seconds
# acc: 91.34 best_acc: 92.48
#
#
#
# Epoch 113 / 200: avg. loss of last 5 iterations 0.018102755234576762 , Time : 38.75161528587341 seconds
# acc: 91.61 best_acc: 92.48
#
#
#
# Epoch 114 / 200: avg. loss of last 5 iterations 0.04937891678418964 , Time : 38.68340253829956 seconds
# acc: 91.72 best_acc: 92.48
#
#
#
# Epoch 115 / 200: avg. loss of last 5 iterations 0.04956983085721731 , Time : 38.708391427993774 seconds
# acc: 91.81 best_acc: 92.48
#
#
#
# Epoch 116 / 200: avg. loss of last 5 iterations 0.018300899863243104 , Time : 38.81031370162964 seconds
# acc: 92.38 best_acc: 92.48
#
#
#
# Epoch 117 / 200: avg. loss of last 5 iterations 0.01755759578663856 , Time : 38.59962201118469 seconds
# acc: 91.48 best_acc: 92.48
#
#
#
# Epoch 118 / 200: avg. loss of last 5 iterations 0.020994235423859208 , Time : 38.87737560272217 seconds
# acc: 92.04 best_acc: 92.48
#
#
#
# Epoch 119 / 200: avg. loss of last 5 iterations 0.014397551846923307 , Time : 38.78263854980469 seconds
# acc: 92.12 best_acc: 92.48
#
#
#
# Epoch 120 / 200: avg. loss of last 5 iterations 0.07760554999113083 , Time : 38.74835443496704 seconds
# acc: 91.59 best_acc: 92.48
#
#
#
# Epoch 121 / 200: avg. loss of last 5 iterations 0.014361910242587327 , Time : 38.697935581207275 seconds
# acc: 92.58 best_acc: 92.48
# Saving..
#
#
#
# Epoch 122 / 200: avg. loss of last 5 iterations 0.029176160879433154 , Time : 38.73457360267639 seconds
# acc: 92.86 best_acc: 92.58
# Saving..
#
#
#
# Epoch 123 / 200: avg. loss of last 5 iterations 0.004922391299623996 , Time : 38.74629473686218 seconds
# acc: 92.9 best_acc: 92.86
# Saving..
#
#
#
# Epoch 124 / 200: avg. loss of last 5 iterations 0.007446969347074628 , Time : 38.69602918624878 seconds
# acc: 93.0 best_acc: 92.9
# Saving..
#
#
#
# Epoch 125 / 200: avg. loss of last 5 iterations 0.012535044367541558 , Time : 38.82066774368286 seconds
# acc: 92.92 best_acc: 93.0
#
#
#
# Epoch 126 / 200: avg. loss of last 5 iterations 0.0024490858893841507 , Time : 38.72341966629028 seconds
# acc: 92.93 best_acc: 93.0
#
#
#
# Epoch 127 / 200: avg. loss of last 5 iterations 0.004573705233633518 , Time : 38.800721406936646 seconds
# acc: 92.92 best_acc: 93.0
#
#
#
# Epoch 128 / 200: avg. loss of last 5 iterations 0.0012166020416771062 , Time : 38.65382099151611 seconds
# acc: 93.15 best_acc: 93.0
# Saving..
#
#
#
# Epoch 129 / 200: avg. loss of last 5 iterations 0.0008466352970572189 , Time : 38.786067485809326 seconds
# acc: 93.03 best_acc: 93.15
#
#
#
# Epoch 130 / 200: avg. loss of last 5 iterations 0.0018656667365576141 , Time : 38.726560831069946 seconds
# acc: 93.1 best_acc: 93.15
#
#
#
# Epoch 131 / 200: avg. loss of last 5 iterations 0.005592405337665696 , Time : 38.671862840652466 seconds
# acc: 93.02 best_acc: 93.15
#
#
#
# Epoch 132 / 200: avg. loss of last 5 iterations 0.004582802089862526 , Time : 38.72285437583923 seconds
# acc: 93.02 best_acc: 93.15
#
#
#
# Epoch 133 / 200: avg. loss of last 5 iterations 0.0014052452053874731 , Time : 38.77330780029297 seconds
# acc: 93.07 best_acc: 93.15
#
#
#
# Epoch 134 / 200: avg. loss of last 5 iterations 0.000870837934780866 , Time : 38.694581747055054 seconds
# acc: 93.09 best_acc: 93.15
#
#
#
# Epoch 135 / 200: avg. loss of last 5 iterations 0.0013773088066955097 , Time : 38.700045347213745 seconds
# acc: 93.04 best_acc: 93.15
#
#
#
# Epoch 136 / 200: avg. loss of last 5 iterations 0.001057286371360533 , Time : 38.800360679626465 seconds
# acc: 93.14 best_acc: 93.15
#
#
#
# Epoch 137 / 200: avg. loss of last 5 iterations 0.006136869237525389 , Time : 38.62989139556885 seconds
# acc: 92.99 best_acc: 93.15
#
#
#
# Epoch 138 / 200: avg. loss of last 5 iterations 0.0012981413514353336 , Time : 38.70953321456909 seconds
# acc: 93.01 best_acc: 93.15
#
#
#
# Epoch 139 / 200: avg. loss of last 5 iterations 0.005553157790564001 , Time : 38.751629114151 seconds
# acc: 93.1 best_acc: 93.15
#
#
#
# Epoch 140 / 200: avg. loss of last 5 iterations 0.008369216229766607 , Time : 38.64319467544556 seconds
# acc: 93.19 best_acc: 93.15
# Saving..
#
#
#
# Epoch 141 / 200: avg. loss of last 5 iterations 0.0036299838597187773 , Time : 38.811199426651 seconds
# acc: 92.99 best_acc: 93.19
#
#
#
# Epoch 142 / 200: avg. loss of last 5 iterations 0.000546098971972242 , Time : 38.81057596206665 seconds
# acc: 93.14 best_acc: 93.19
#
#
#
# Epoch 143 / 200: avg. loss of last 5 iterations 0.004497335021733306 , Time : 38.694974422454834 seconds
# acc: 92.95 best_acc: 93.19
#
#
#
# Epoch 144 / 200: avg. loss of last 5 iterations 0.0013811732220347039 , Time : 38.595240116119385 seconds
# acc: 93.08 best_acc: 93.19
#
#
#
# Epoch 145 / 200: avg. loss of last 5 iterations 0.0010275761334924028 , Time : 38.81642961502075 seconds
# acc: 93.06 best_acc: 93.19
#
#
#
# Epoch 146 / 200: avg. loss of last 5 iterations 0.006946397409774363 , Time : 38.7421293258667 seconds
# acc: 93.04 best_acc: 93.19
#
#
#
# Epoch 147 / 200: avg. loss of last 5 iterations 0.0030878674995619805 , Time : 38.688575744628906 seconds
# acc: 93.17 best_acc: 93.19
#
#
#
# Epoch 148 / 200: avg. loss of last 5 iterations 0.0021714493428589775 , Time : 38.68841075897217 seconds
# acc: 93.08 best_acc: 93.19
#
#
#
# Epoch 149 / 200: avg. loss of last 5 iterations 0.0012357954932667782 , Time : 38.670685052871704 seconds
# acc: 93.08 best_acc: 93.19
#
#
#
# Epoch 150 / 200: avg. loss of last 5 iterations 0.0010522638462134638 , Time : 38.959717750549316 seconds
# acc: 93.01 best_acc: 93.19
#
#
#
# Epoch 151 / 200: avg. loss of last 5 iterations 0.0017277332415687851 , Time : 38.641475439071655 seconds
# acc: 92.99 best_acc: 93.19
#
#
#
# Epoch 152 / 200: avg. loss of last 5 iterations 0.0008019631786737591 , Time : 38.692333698272705 seconds
# acc: 93.17 best_acc: 93.19
#
#
#
# Epoch 153 / 200: avg. loss of last 5 iterations 0.0018318315065698697 , Time : 38.6202654838562 seconds
# acc: 93.04 best_acc: 93.19
#
#
#
# Epoch 154 / 200: avg. loss of last 5 iterations 0.0013648716048919596 , Time : 38.65957260131836 seconds
# acc: 93.19 best_acc: 93.19
#
#
#
# Epoch 155 / 200: avg. loss of last 5 iterations 0.002844215149525553 , Time : 38.764216899871826 seconds
# acc: 93.11 best_acc: 93.19
#
#
#
# Epoch 156 / 200: avg. loss of last 5 iterations 0.0016998533959849738 , Time : 38.467047929763794 seconds
# acc: 93.13 best_acc: 93.19
#
#
#
# Epoch 157 / 200: avg. loss of last 5 iterations 0.0028879260877147316 , Time : 38.449357748031616 seconds
# acc: 93.03 best_acc: 93.19
#
#
#
# Epoch 158 / 200: avg. loss of last 5 iterations 0.0010473898524651303 , Time : 38.39169979095459 seconds
# acc: 93.17 best_acc: 93.19
#
#
#
# Epoch 159 / 200: avg. loss of last 5 iterations 0.0009107424062676728 , Time : 38.4041633605957 seconds
# acc: 93.23 best_acc: 93.19
# Saving..
#
#
#
# Epoch 160 / 200: avg. loss of last 5 iterations 0.00030325476545840503 , Time : 38.58718824386597 seconds
# acc: 93.2 best_acc: 93.23
#
#
#
# Epoch 161 / 200: avg. loss of last 5 iterations 0.001134463751441217 , Time : 38.95086479187012 seconds
# acc: 93.24 best_acc: 93.23
# Saving..
#
#
#
# Epoch 162 / 200: avg. loss of last 5 iterations 0.0012936560488014948 , Time : 38.80030179023743 seconds
# acc: 93.21 best_acc: 93.24
#
#
#
# Epoch 163 / 200: avg. loss of last 5 iterations 0.0004638362006517127 , Time : 38.683523178100586 seconds
# acc: 93.2 best_acc: 93.24
#
#
#
# Epoch 164 / 200: avg. loss of last 5 iterations 0.0014855135057587176 , Time : 38.78124189376831 seconds
# acc: 93.2 best_acc: 93.24
#
#
#
# Epoch 165 / 200: avg. loss of last 5 iterations 0.0021396664014901035 , Time : 38.74135661125183 seconds
# acc: 93.15 best_acc: 93.24
#
#
#
# Epoch 166 / 200: avg. loss of last 5 iterations 0.0006587397685507313 , Time : 38.73920202255249 seconds
# acc: 93.2 best_acc: 93.24
#
#
#
# Epoch 167 / 200: avg. loss of last 5 iterations 0.0007753484067507088 , Time : 38.5791871547699 seconds
# acc: 93.24 best_acc: 93.24
#
#
#
# Epoch 168 / 200: avg. loss of last 5 iterations 0.0024521381565136835 , Time : 38.81482005119324 seconds
# acc: 93.12 best_acc: 93.24
#
#
#
# Epoch 169 / 200: avg. loss of last 5 iterations 0.0003213433166820323 , Time : 38.68606972694397 seconds
# acc: 93.13 best_acc: 93.24
#
#
#
# Epoch 170 / 200: avg. loss of last 5 iterations 0.007635235345514957 , Time : 38.65503644943237 seconds
# acc: 93.2 best_acc: 93.24
#
#
#
# Epoch 171 / 200: avg. loss of last 5 iterations 0.000391201567981625 , Time : 38.85325503349304 seconds
# acc: 93.23 best_acc: 93.24
#
#
#
# Epoch 172 / 200: avg. loss of last 5 iterations 0.0020608742372132836 , Time : 38.80427312850952 seconds
# acc: 93.1 best_acc: 93.24
#
#
#
# Epoch 173 / 200: avg. loss of last 5 iterations 0.0011172811855431064 , Time : 38.786266565322876 seconds
# acc: 93.1 best_acc: 93.24
#
#
#
# Epoch 174 / 200: avg. loss of last 5 iterations 0.0012798588897567243 , Time : 38.6393096446991 seconds
# acc: 93.09 best_acc: 93.24
#
#
#
# Epoch 175 / 200: avg. loss of last 5 iterations 0.0026652308763004838 , Time : 38.70777940750122 seconds
# acc: 93.0 best_acc: 93.24
#
#
#
# Epoch 176 / 200: avg. loss of last 5 iterations 0.0014964438436436468 , Time : 38.667086362838745 seconds
# acc: 93.02 best_acc: 93.24
#
#
#
# Epoch 177 / 200: avg. loss of last 5 iterations 0.0014985597284976394 , Time : 38.70258331298828 seconds
# acc: 93.28 best_acc: 93.24
# Saving..
#
#
#
# Epoch 178 / 200: avg. loss of last 5 iterations 0.00236523852126993 , Time : 38.70863628387451 seconds
# acc: 93.15 best_acc: 93.28
#
#
#
# Epoch 179 / 200: avg. loss of last 5 iterations 0.0003932036430342123 , Time : 38.65141320228577 seconds
# acc: 93.3 best_acc: 93.28
# Saving..
#
#
#
# Epoch 180 / 200: avg. loss of last 5 iterations 0.0036787427627132272 , Time : 38.71651744842529 seconds
# acc: 93.28 best_acc: 93.3
#
#
#
# Epoch 181 / 200: avg. loss of last 5 iterations 0.02673685325717088 , Time : 38.76046800613403 seconds
# acc: 93.31 best_acc: 93.3
# Saving..
#
#
#
# Epoch 182 / 200: avg. loss of last 5 iterations 0.0007987461096490734 , Time : 38.812618255615234 seconds
# acc: 93.35 best_acc: 93.31
# Saving..
#
#
#
# Epoch 183 / 200: avg. loss of last 5 iterations 0.002438401652034372 , Time : 38.633925914764404 seconds
# acc: 93.38 best_acc: 93.35
# Saving..
#
#
#
# Epoch 184 / 200: avg. loss of last 5 iterations 0.0003640052724222187 , Time : 38.79234313964844 seconds
# acc: 93.33 best_acc: 93.38
#
#
#
# Epoch 185 / 200: avg. loss of last 5 iterations 0.0032457913912367076 , Time : 38.72975182533264 seconds
# acc: 93.33 best_acc: 93.38
#
#
#
# Epoch 186 / 200: avg. loss of last 5 iterations 0.010213611216749996 , Time : 38.67586851119995 seconds
# acc: 93.3 best_acc: 93.38
#
#
#
# Epoch 187 / 200: avg. loss of last 5 iterations 0.002660555430338718 , Time : 38.87023186683655 seconds
# acc: 93.35 best_acc: 93.38
#
#
#
# Epoch 188 / 200: avg. loss of last 5 iterations 0.0009678590984549373 , Time : 38.64599633216858 seconds
# acc: 93.33 best_acc: 93.38
#
#
#
# Epoch 189 / 200: avg. loss of last 5 iterations 0.0005635727400658652 , Time : 38.7459077835083 seconds
# acc: 93.3 best_acc: 93.38
#
#
#
# Epoch 190 / 200: avg. loss of last 5 iterations 0.01330454416165594 , Time : 38.65735220909119 seconds
# acc: 93.31 best_acc: 93.38
#
#
#
# Epoch 191 / 200: avg. loss of last 5 iterations 0.0012715944350929931 , Time : 38.76329731941223 seconds
# acc: 93.31 best_acc: 93.38
#
#
#
# Epoch 192 / 200: avg. loss of last 5 iterations 0.0010262999217957257 , Time : 38.70492625236511 seconds
# acc: 93.25 best_acc: 93.38
#
#
#
# Epoch 193 / 200: avg. loss of last 5 iterations 0.0016248327963694464 , Time : 38.720503091812134 seconds
# acc: 93.26 best_acc: 93.38
#
#
#
# Epoch 194 / 200: avg. loss of last 5 iterations 0.0008329634365509264 , Time : 38.87851548194885 seconds
# acc: 93.26 best_acc: 93.38
#
#
#
# Epoch 195 / 200: avg. loss of last 5 iterations 0.0002933779422164662 , Time : 38.68285846710205 seconds
# acc: 93.29 best_acc: 93.38
#
#
#
# Epoch 196 / 200: avg. loss of last 5 iterations 0.000499270333966706 , Time : 38.65031862258911 seconds
# acc: 93.32 best_acc: 93.38
#
#
#
# Epoch 197 / 200: avg. loss of last 5 iterations 0.014561223599594086 , Time : 38.8247504234314 seconds
# acc: 93.27 best_acc: 93.38
#
#
#
# Epoch 198 / 200: avg. loss of last 5 iterations 0.001133213449793402 , Time : 38.813117265701294 seconds
# acc: 93.26 best_acc: 93.38
#
#
#
# Epoch 199 / 200: avg. loss of last 5 iterations 0.0006766542050172575 , Time : 38.604353189468384 seconds
# acc: 93.23 best_acc: 93.38
#
#
#
# Epoch 200 / 200: avg. loss of last 5 iterations 0.0008906733652111143 , Time : 38.72818088531494 seconds
# acc: 93.26 best_acc: 93.38

# %% [markdown]
# ### 4.3 The Loss Curve
# Loss curve is visualized.

# %%
plt.plot(loss_history)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# ### 4.4 Quantitative Analysis
#
# We can analyze the accuracy of the predictions as follows.

# %%
correct = 0
total = 0
with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(testloader):
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = net(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 93 %

# %%
print('saving' ,'acc:',best_acc)
# Out:
# saving acc: 93.38

# %% [markdown]
# ### 5 Results
#
# Accuracy vs epoch is plotted according to the test results.

# %%
plt.plot(historyy)
plt.xlabel('Epoch number')
plt.ylabel('Accuracy')
plt.show()
print(historyy)
# Out:
# [28.27, 38.74, 44.89, 47.36, 51.94, 59.5, 57.87, 68.63, 70.4, 74.33, 75.67, 76.4, 75.11, 77.82, 78.5, 81.87, 80.77, 81.96, 81.46, 81.17, 83.36, 83.48, 83.75, 82.83, 85.0, 83.03, 86.05, 84.77, 85.54, 82.85, 84.78, 84.32, 84.84, 85.32, 86.36, 84.24, 85.79, 84.72, 85.2, 85.9, 85.19, 84.51, 86.18, 85.49, 87.46, 83.72, 85.41, 86.89, 87.02, 85.41, 86.4, 86.71, 87.27, 86.23, 87.56, 83.48, 84.41, 88.7, 85.72, 87.85, 91.33, 91.63, 91.53, 91.96, 91.78, 91.97, 92.11, 91.98, 92.18, 92.27, 91.81, 92.11, 92.46, 92.31, 92.09, 92.28, 92.09, 92.01, 92.02, 92.05, 92.29, 92.25, 92.27, 91.83, 92.04, 91.77, 92.02, 92.32, 92.26, 91.94, 92.24, 92.21, 91.83, 92.48, 92.15, 91.98, 92.17, 91.87, 91.72, 92.03, 91.69, 91.92, 91.93, 92.08, 91.16, 91.88, 91.9, 91.56, 92.0, 91.78, 90.81, 91.34, 91.61, 91.72, 91.81, 92.38, 91.48, 92.04, 92.12, 91.59, 92.58, 92.86, 92.9, 93.0, 92.92, 92.93, 92.92, 93.15, 93.03, 93.1, 93.02, 93.02, 93.07, 93.09, 93.04, 93.14, 92.99, 93.01, 93.1, 93.19, 92.99, 93.14, 92.95, 93.08, 93.06, 93.04, 93.17, 93.08, 93.08, 93.01, 92.99, 93.17, 93.04, 93.19, 93.11, 93.13, 93.03, 93.17, 93.23, 93.2, 93.24, 93.21, 93.2, 93.2, 93.15, 93.2, 93.24, 93.12, 93.13, 93.2, 93.23, 93.1, 93.1, 93.09, 93.0, 93.02, 93.28, 93.15, 93.3, 93.28, 93.31, 93.35, 93.38, 93.33, 93.33, 93.3, 93.35, 93.33, 93.3, 93.31, 93.31, 93.25, 93.26, 93.26, 93.29, 93.32, 93.27, 93.26, 93.23, 93.26]
