# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
import torchvision.transforms as transforms
import sys

import matplotlib.pyplot as plt 
import time   

import os
import argparse

# %% [markdown]
# ### 1.1 Enable GPU
#
# From "Edit -> Notebook Settings -> Hardware accelerator" select GPU. With the following we will specify to PyTorch that we want to use the GPU.

# %%
if torch.cuda.is_available():
  print("Cuda (GPU support) is available and enabled!")
  device = torch.device("cuda")
else:
  print("Cuda (GPU support) is not available :(")
  device = torch.device("cpu")
# Out:
# Cuda (GPU support) is available and enabled!

# %% [markdown]
# ### 2 Model Definition
#
#
# In the original paper there are two different frameworks; ResNet and VGG. In this section, different models for different frameworks are created. However, in the original paper different normalization methods are applied in these frameworks and as mentioned the authors of the paper propose a new method which is called momentum Batch Normalization. In ResNet and VGG frameworks a naive batch normalization block is used and modified according to the proposed Momentum Batch Normalization method. On the other hand, Pytorch functions are used directly for other normalization methods such as Group Normalization, Layer Normalization, Instance Normalization and Batch Normalization for ResNet.

# %% [markdown]
# ### 2.1 ResNet
#
# ResNet18, ResNet34 and ResNet50 architectures are defined according to the original paper as folllows.

# %%
class BasicBlock(nn.Module):
    coefficient = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.GroupNorm(32, planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.GroupNorm(32, planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.coefficient*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.coefficient*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.GroupNorm(32, self.coefficient*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    coefficient = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.GroupNorm(32, planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.GroupNorm(32, planes)
        self.conv3 = nn.Conv2d(planes, self.coefficient *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.GroupNorm(32, self.coefficient*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.coefficient*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.coefficient*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.GroupNorm(32, self.coefficient*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.GroupNorm(32, 64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.coefficient, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.coefficient
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

# %% [markdown]
# ### 2.2 VGG
#
# VGG11 and VGG16 architectures are defined according to the original paper as folllows.

# %%
configuration = {
    'VGG11': [64, 'pool', 128, 'pool', 256, 256, 'pool', 512, 512, 'pool', 512, 512, 'pool'],
    'VGG16': [64, 64, 'pool', 128, 128, 'pool', 256, 256, 256, 'pool', 512, 512, 512, 'pool', 512, 512, 512, 'pool']
}


class VGG(nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(configuration[vgg_name])
        self.classifier = nn.Linear(512, 100)

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

    def _make_layers(self, configuration):
        layers = []
        in_channels = 3
        for x in configuration:
            if x == 'pool':
                layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [nn.Conv2d(in_channels, x, kernel_size=3, padding=1),
                           nn.BatchNorm2d(x),
                           nn.ReLU(inplace=True)]
                in_channels = x
        layers += [nn.AvgPool2d(kernel_size=1, stride=1)]
        return nn.Sequential(*layers)

# %% [markdown]
# ## 3 The Dataset
#
# In the original paper authors used CIFAR10 and CIFAR100 datasets. In this section torchvision function is used to load train/test datasets;
#
# *   There are 50000 training images and 10000 test images for  10 different classes for CIFAR10
# *   There are 50000 training images and 10000 test images for 100 different classes for CIFAR100.
#
# In the original paper, authors mentions standard data augmentation and preprocessing techniques are used but any specific parameters were not given in the paper or in the supplementary material of the paper. Therefore, data augmentation and preprocessing techniques are taken from the literature and applied to the datasets.

# %%
# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize((0, 0, 0), (1, 1, 1)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0, 0, 0), (1, 1, 1)),
])

###################
batch_size=32 #batch size (2 per gpu)
m0=32 #ideal batch size
######################


trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2) # 4 gpu

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# ==> Preparing data..
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ### 4 Define and Train Model
# In this section user can choose the model between the ResNet18, ResNet34, ResNet50, VGG11 and VGG16 frameworks.

# %% [markdown]
# ### 4.1 Define Loss Function and the Optimizer
#
# Instance is created for the model based on the choice.
#
# In the original paper authors used Stochastic Gradient Descent for the optimization with the momentum 0.9 and weight decay 0.0001 paramaeters set. In the experiments these parameters and optimization method from the paper are preserved.
#
# Since the criterion for the loss function is not specified exactly in the original paper Cross-Entropy Loss method is chosen in the experiments.

# %%
sys.argv=['']
del sys


best_acc = 0  # best test accuracy
start_epoch = 1  


# Model
print('==> Building model..')

#net = VGG('VGG11')
# net = VGG('VGG16')
net = ResNet18()
# net = ResNet34()
# net = ResNet50()

net = net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.1*batch_size/64,
                      momentum=0.9, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[60, 120, 180], gamma=0.1)
# Out:
# ==> Building model..

# %% [markdown]
# ### 4.2 Train the Model
#
# In the original paper, authors propose a new method in order to train large datasets with small batch-sizes for insufficient memory resources. Therefore, in the experiments considerably smaller batch sizes are used and it extends the training times. In order to overcome high training times problem GPU usage becomes a necessity and cuda is used in the experiments with Colab Pro.

# %%
# Training and Accuracy Calculation
def train(verbose=True):
    
    loss_history=[]
    net.train()
    correct = 0
    total = 0
    for epoch in range(start_epoch, start_epoch+epoch_number):
      
      start = time.time()
      for batch_idx, (inputs, targets) in enumerate(trainloader):
          inputs, targets = inputs.to(device), targets.to(device)
          
          optimizer.zero_grad()
          outputs = net(inputs)
          loss = criterion(outputs, targets)
          loss.backward()
          optimizer.step()


          loss_history.append(loss.item()) 

      end = time.time()
      if verbose: print(f'Epoch {epoch} / {epoch_number}: avg. loss of last 5 iterations {np.sum(loss_history[:-6:-1])/5} , Time : {end - start} seconds')            

      global best_acc
      global test_loss
      net.eval()
      test_loss = 0
      correct = 0
      total = 0
      with torch.no_grad():
          for batch_idx, (inputs, targets) in enumerate(testloader):
              inputs, targets = inputs.to(device), targets.to(device)
              outputs = net(inputs)  
              _, predicted = outputs.max(1)
              total += targets.size(0)
              correct += predicted.eq(targets).sum().item()       


      acc = 100.*correct/total
      historyy.append(acc)

      print('acc:',acc,'best_acc:',best_acc)
      if acc > best_acc:
          print('Saving..' )
          
          state = {
              'net': net.state_dict(),
              'acc': acc,
              'epoch': epoch,
          }
          best_acc = acc
          
      print('\n\n') 
      scheduler.step() 
    return loss_history

# %%
epoch_number=200
historyy=[]
losses=[]


loss_history=train()
# Out:
# Epoch 1 / 200: avg. loss of last 5 iterations 2.1162545919418334 , Time : 40.08829140663147 seconds
# acc: 30.77 best_acc: 0
# Saving..
#
#
#
# Epoch 2 / 200: avg. loss of last 5 iterations 1.5796051263809203 , Time : 40.00772023200989 seconds
# acc: 42.43 best_acc: 30.77
# Saving..
#
#
#
# Epoch 3 / 200: avg. loss of last 5 iterations 1.2764170169830322 , Time : 40.06552863121033 seconds
# acc: 51.78 best_acc: 42.43
# Saving..
#
#
#
# Epoch 4 / 200: avg. loss of last 5 iterations 1.2005673408508302 , Time : 39.9910569190979 seconds
# acc: 56.15 best_acc: 51.78
# Saving..
#
#
#
# Epoch 5 / 200: avg. loss of last 5 iterations 0.922778868675232 , Time : 39.988463401794434 seconds
# acc: 67.66 best_acc: 56.15
# Saving..
#
#
#
# Epoch 6 / 200: avg. loss of last 5 iterations 0.8233327865600586 , Time : 39.995471715927124 seconds
# acc: 71.68 best_acc: 67.66
# Saving..
#
#
#
# Epoch 7 / 200: avg. loss of last 5 iterations 0.8819505095481872 , Time : 40.04510021209717 seconds
# acc: 74.96 best_acc: 71.68
# Saving..
#
#
#
# Epoch 8 / 200: avg. loss of last 5 iterations 0.8285752058029174 , Time : 39.95612621307373 seconds
# acc: 73.8 best_acc: 74.96
#
#
#
# Epoch 9 / 200: avg. loss of last 5 iterations 0.6332381963729858 , Time : 40.007081747055054 seconds
# acc: 79.32 best_acc: 74.96
# Saving..
#
#
#
# Epoch 10 / 200: avg. loss of last 5 iterations 0.5680604994297027 , Time : 39.960001945495605 seconds
# acc: 79.34 best_acc: 79.32
# Saving..
#
#
#
# Epoch 11 / 200: avg. loss of last 5 iterations 0.5750977694988251 , Time : 39.94838333129883 seconds
# acc: 80.44 best_acc: 79.34
# Saving..
#
#
#
# Epoch 12 / 200: avg. loss of last 5 iterations 0.4374268114566803 , Time : 39.78128361701965 seconds
# acc: 82.26 best_acc: 80.44
# Saving..
#
#
#
# Epoch 13 / 200: avg. loss of last 5 iterations 0.5451294362545014 , Time : 39.946489572525024 seconds
# acc: 81.06 best_acc: 82.26
#
#
#
# Epoch 14 / 200: avg. loss of last 5 iterations 0.4597398847341537 , Time : 40.14222526550293 seconds
# acc: 83.16 best_acc: 82.26
# Saving..
#
#
#
# Epoch 15 / 200: avg. loss of last 5 iterations 0.5120690524578094 , Time : 39.975096702575684 seconds
# acc: 83.72 best_acc: 83.16
# Saving..
#
#
#
# Epoch 16 / 200: avg. loss of last 5 iterations 0.47238729894161224 , Time : 39.799826860427856 seconds
# acc: 83.03 best_acc: 83.72
#
#
#
# Epoch 17 / 200: avg. loss of last 5 iterations 0.349667963385582 , Time : 40.005390882492065 seconds
# acc: 83.73 best_acc: 83.72
# Saving..
#
#
#
# Epoch 18 / 200: avg. loss of last 5 iterations 0.33302552402019503 , Time : 39.925952672958374 seconds
# acc: 84.22 best_acc: 83.73
# Saving..
#
#
#
# Epoch 19 / 200: avg. loss of last 5 iterations 0.2953028529882431 , Time : 39.9638295173645 seconds
# acc: 85.37 best_acc: 84.22
# Saving..
#
#
#
# Epoch 20 / 200: avg. loss of last 5 iterations 0.3957022100687027 , Time : 39.970080852508545 seconds
# acc: 84.66 best_acc: 85.37
#
#
#
# Epoch 21 / 200: avg. loss of last 5 iterations 0.49707524180412294 , Time : 39.92762041091919 seconds
# acc: 84.76 best_acc: 85.37
#
#
#
# Epoch 22 / 200: avg. loss of last 5 iterations 0.315859854221344 , Time : 39.91401028633118 seconds
# acc: 85.86 best_acc: 85.37
# Saving..
#
#
#
# Epoch 23 / 200: avg. loss of last 5 iterations 0.4213030934333801 , Time : 40.00334310531616 seconds
# acc: 85.1 best_acc: 85.86
#
#
#
# Epoch 24 / 200: avg. loss of last 5 iterations 0.2695250421762466 , Time : 39.95319128036499 seconds
# acc: 86.16 best_acc: 85.86
# Saving..
#
#
#
# Epoch 25 / 200: avg. loss of last 5 iterations 0.33271645903587344 , Time : 39.933040380477905 seconds
# acc: 84.32 best_acc: 86.16
#
#
#
# Epoch 26 / 200: avg. loss of last 5 iterations 0.47357343435287474 , Time : 39.89941048622131 seconds
# acc: 86.6 best_acc: 86.16
# Saving..
#
#
#
# Epoch 27 / 200: avg. loss of last 5 iterations 0.3669187933206558 , Time : 39.90015244483948 seconds
# acc: 84.78 best_acc: 86.6
#
#
#
# Epoch 28 / 200: avg. loss of last 5 iterations 0.21245381534099578 , Time : 39.87601113319397 seconds
# acc: 86.97 best_acc: 86.6
# Saving..
#
#
#
# Epoch 29 / 200: avg. loss of last 5 iterations 0.27814358472824097 , Time : 39.84781455993652 seconds
# acc: 86.41 best_acc: 86.97
#
#
#
# Epoch 30 / 200: avg. loss of last 5 iterations 0.3460425853729248 , Time : 39.86523103713989 seconds
# acc: 86.35 best_acc: 86.97
#
#
#
# Epoch 31 / 200: avg. loss of last 5 iterations 0.2967324614524841 , Time : 39.70140743255615 seconds
# acc: 88.74 best_acc: 86.97
# Saving..
#
#
#
# Epoch 32 / 200: avg. loss of last 5 iterations 0.32569763958454134 , Time : 39.73812961578369 seconds
# acc: 85.82 best_acc: 88.74
#
#
#
# Epoch 33 / 200: avg. loss of last 5 iterations 0.2457361564040184 , Time : 39.681910276412964 seconds
# acc: 88.05 best_acc: 88.74
#
#
#
# Epoch 34 / 200: avg. loss of last 5 iterations 0.3452544346451759 , Time : 39.67716336250305 seconds
# acc: 87.89 best_acc: 88.74
#
#
#
# Epoch 35 / 200: avg. loss of last 5 iterations 0.24859872460365295 , Time : 39.64334511756897 seconds
# acc: 88.94 best_acc: 88.74
# Saving..
#
#
#
# Epoch 36 / 200: avg. loss of last 5 iterations 0.2772027164697647 , Time : 39.880269050598145 seconds
# acc: 87.02 best_acc: 88.94
#
#
#
# Epoch 37 / 200: avg. loss of last 5 iterations 0.21090324148535727 , Time : 39.77293252944946 seconds
# acc: 88.69 best_acc: 88.94
#
#
#
# Epoch 38 / 200: avg. loss of last 5 iterations 0.263691845536232 , Time : 39.64716196060181 seconds
# acc: 88.04 best_acc: 88.94
#
#
#
# Epoch 39 / 200: avg. loss of last 5 iterations 0.20205520689487458 , Time : 39.75693130493164 seconds
# acc: 87.7 best_acc: 88.94
#
#
#
# Epoch 40 / 200: avg. loss of last 5 iterations 0.30331796407699585 , Time : 39.64234685897827 seconds
# acc: 86.37 best_acc: 88.94
#
#
#
# Epoch 41 / 200: avg. loss of last 5 iterations 0.2796669572591782 , Time : 39.678396224975586 seconds
# acc: 87.22 best_acc: 88.94
#
#
#
# Epoch 42 / 200: avg. loss of last 5 iterations 0.37500727772712705 , Time : 39.662741899490356 seconds
# acc: 87.21 best_acc: 88.94
#
#
#
# Epoch 43 / 200: avg. loss of last 5 iterations 0.24687933325767517 , Time : 39.766143798828125 seconds
# acc: 88.33 best_acc: 88.94
#
#
#
# Epoch 44 / 200: avg. loss of last 5 iterations 0.22103381156921387 , Time : 39.64941644668579 seconds
# acc: 83.03 best_acc: 88.94
#
#
#
# Epoch 45 / 200: avg. loss of last 5 iterations 0.2719270303845406 , Time : 39.646966218948364 seconds
# acc: 86.93 best_acc: 88.94
#
#
#
# Epoch 46 / 200: avg. loss of last 5 iterations 0.34387095272541046 , Time : 39.692445039749146 seconds
# acc: 88.88 best_acc: 88.94
#
#
#
# Epoch 47 / 200: avg. loss of last 5 iterations 0.2506383202970028 , Time : 39.78125262260437 seconds
# acc: 88.25 best_acc: 88.94
#
#
#
# Epoch 48 / 200: avg. loss of last 5 iterations 0.2777309238910675 , Time : 39.73631691932678 seconds
# acc: 87.3 best_acc: 88.94
#
#
#
# Epoch 49 / 200: avg. loss of last 5 iterations 0.2576506108045578 , Time : 39.76757502555847 seconds
# acc: 89.29 best_acc: 88.94
# Saving..
#
#
#
# Epoch 50 / 200: avg. loss of last 5 iterations 0.23881119191646577 , Time : 39.778327226638794 seconds
# acc: 86.78 best_acc: 89.29
#
#
#
# Epoch 51 / 200: avg. loss of last 5 iterations 0.2512748271226883 , Time : 39.78772735595703 seconds
# acc: 86.14 best_acc: 89.29
#
#
#
# Epoch 52 / 200: avg. loss of last 5 iterations 0.3371575117111206 , Time : 39.69542121887207 seconds
# acc: 87.35 best_acc: 89.29
#
#
#
# Epoch 53 / 200: avg. loss of last 5 iterations 0.2294709324836731 , Time : 39.794360876083374 seconds
# acc: 87.84 best_acc: 89.29
#
#
#
# Epoch 54 / 200: avg. loss of last 5 iterations 0.20595691204071045 , Time : 39.80243539810181 seconds
# acc: 87.04 best_acc: 89.29
#
#
#
# Epoch 55 / 200: avg. loss of last 5 iterations 0.2241276316344738 , Time : 39.70095467567444 seconds
# acc: 88.53 best_acc: 89.29
#
#
#
# Epoch 56 / 200: avg. loss of last 5 iterations 0.23399385511875154 , Time : 39.700698137283325 seconds
# acc: 87.98 best_acc: 89.29
#
#
#
# Epoch 57 / 200: avg. loss of last 5 iterations 0.1849523290991783 , Time : 39.68338751792908 seconds
# acc: 88.07 best_acc: 89.29
#
#
#
# Epoch 58 / 200: avg. loss of last 5 iterations 0.167981830984354 , Time : 40.01927900314331 seconds
# acc: 88.16 best_acc: 89.29
#
#
#
# Epoch 59 / 200: avg. loss of last 5 iterations 0.2642444148659706 , Time : 39.73971605300903 seconds
# acc: 86.06 best_acc: 89.29
#
#
#
# Epoch 60 / 200: avg. loss of last 5 iterations 0.19356275200843812 , Time : 39.68283271789551 seconds
# acc: 89.74 best_acc: 89.29
# Saving..
#
#
#
# Epoch 61 / 200: avg. loss of last 5 iterations 0.05225285831838846 , Time : 39.65498208999634 seconds
# acc: 92.62 best_acc: 89.74
# Saving..
#
#
#
# Epoch 62 / 200: avg. loss of last 5 iterations 0.11702640671283007 , Time : 39.73252058029175 seconds
# acc: 92.62 best_acc: 92.62
#
#
#
# Epoch 63 / 200: avg. loss of last 5 iterations 0.15063645271584392 , Time : 39.77483105659485 seconds
# acc: 93.03 best_acc: 92.62
# Saving..
#
#
#
# Epoch 64 / 200: avg. loss of last 5 iterations 0.09826704019214957 , Time : 39.68194079399109 seconds
# acc: 92.77 best_acc: 93.03
#
#
#
# Epoch 65 / 200: avg. loss of last 5 iterations 0.02404441451653838 , Time : 39.70444893836975 seconds
# acc: 92.95 best_acc: 93.03
#
#
#
# Epoch 66 / 200: avg. loss of last 5 iterations 0.051826884504407644 , Time : 39.734198808670044 seconds
# acc: 93.01 best_acc: 93.03
#
#
#
# Epoch 67 / 200: avg. loss of last 5 iterations 0.0981074556708336 , Time : 39.77277660369873 seconds
# acc: 93.01 best_acc: 93.03
#
#
#
# Epoch 68 / 200: avg. loss of last 5 iterations 0.0350998904556036 , Time : 39.72022533416748 seconds
# acc: 92.77 best_acc: 93.03
#
#
#
# Epoch 69 / 200: avg. loss of last 5 iterations 0.033598851622082294 , Time : 39.63740921020508 seconds
# acc: 92.92 best_acc: 93.03
#
#
#
# Epoch 70 / 200: avg. loss of last 5 iterations 0.02385171710047871 , Time : 39.73945665359497 seconds
# acc: 93.1 best_acc: 93.03
# Saving..
#
#
#
# Epoch 71 / 200: avg. loss of last 5 iterations 0.04339986015111208 , Time : 39.87700581550598 seconds
# acc: 92.86 best_acc: 93.1
#
#
#
# Epoch 72 / 200: avg. loss of last 5 iterations 0.0704034859314561 , Time : 40.0238676071167 seconds
# acc: 92.84 best_acc: 93.1
#
#
#
# Epoch 73 / 200: avg. loss of last 5 iterations 0.07195822030771523 , Time : 40.08295822143555 seconds
# acc: 93.25 best_acc: 93.1
# Saving..
#
#
#
# Epoch 74 / 200: avg. loss of last 5 iterations 0.028721290361136197 , Time : 40.02687358856201 seconds
# acc: 92.86 best_acc: 93.25
#
#
#
# Epoch 75 / 200: avg. loss of last 5 iterations 0.032397877983748914 , Time : 39.966805934906006 seconds
# acc: 93.36 best_acc: 93.25
# Saving..
#
#
#
# Epoch 76 / 200: avg. loss of last 5 iterations 0.021543946536257862 , Time : 39.92488741874695 seconds
# acc: 93.27 best_acc: 93.36
#
#
#
# Epoch 77 / 200: avg. loss of last 5 iterations 0.043968203803524376 , Time : 39.97318148612976 seconds
# acc: 93.38 best_acc: 93.36
# Saving..
#
#
#
# Epoch 78 / 200: avg. loss of last 5 iterations 0.01741563156247139 , Time : 39.898709297180176 seconds
# acc: 92.92 best_acc: 93.38
#
#
#
# Epoch 79 / 200: avg. loss of last 5 iterations 0.021923775121103974 , Time : 39.96936869621277 seconds
# acc: 93.06 best_acc: 93.38
#
#
#
# Epoch 80 / 200: avg. loss of last 5 iterations 0.022073783935047685 , Time : 39.922080516815186 seconds
# acc: 93.28 best_acc: 93.38
#
#
#
# Epoch 81 / 200: avg. loss of last 5 iterations 0.036767642479389906 , Time : 39.80201530456543 seconds
# acc: 93.25 best_acc: 93.38
#
#
#
# Epoch 82 / 200: avg. loss of last 5 iterations 0.018547115661203862 , Time : 39.917168855667114 seconds
# acc: 93.12 best_acc: 93.38
#
#
#
# Epoch 83 / 200: avg. loss of last 5 iterations 0.008531103609129786 , Time : 39.90437459945679 seconds
# acc: 93.21 best_acc: 93.38
#
#
#
# Epoch 84 / 200: avg. loss of last 5 iterations 0.023629733209963887 , Time : 39.94228386878967 seconds
# acc: 93.1 best_acc: 93.38
#
#
#
# Epoch 85 / 200: avg. loss of last 5 iterations 0.014384322240948677 , Time : 39.95385789871216 seconds
# acc: 93.28 best_acc: 93.38
#
#
#
# Epoch 86 / 200: avg. loss of last 5 iterations 0.006436825555283576 , Time : 39.8656222820282 seconds
# acc: 93.18 best_acc: 93.38
#
#
#
# Epoch 87 / 200: avg. loss of last 5 iterations 0.011075098405126483 , Time : 39.86754250526428 seconds
# acc: 93.2 best_acc: 93.38
#
#
#
# Epoch 88 / 200: avg. loss of last 5 iterations 0.012403082230594008 , Time : 39.9307541847229 seconds
# acc: 92.99 best_acc: 93.38
#
#
#
# Epoch 89 / 200: avg. loss of last 5 iterations 0.03441944370279089 , Time : 39.906737089157104 seconds
# acc: 93.01 best_acc: 93.38
#
#
#
# Epoch 90 / 200: avg. loss of last 5 iterations 0.006320524279726669 , Time : 39.826141357421875 seconds
# acc: 93.33 best_acc: 93.38
#
#
#
# Epoch 91 / 200: avg. loss of last 5 iterations 0.005197350541129709 , Time : 39.80427861213684 seconds
# acc: 93.21 best_acc: 93.38
#
#
#
# Epoch 92 / 200: avg. loss of last 5 iterations 0.012153225261135958 , Time : 39.90508484840393 seconds
# acc: 93.0 best_acc: 93.38
#
#
#
# Epoch 93 / 200: avg. loss of last 5 iterations 0.007626673654885963 , Time : 39.92023205757141 seconds
# acc: 93.17 best_acc: 93.38
#
#
#
# Epoch 94 / 200: avg. loss of last 5 iterations 0.011817267630249262 , Time : 40.0224974155426 seconds
# acc: 93.24 best_acc: 93.38
#
#
#
# Epoch 95 / 200: avg. loss of last 5 iterations 0.008404929027892648 , Time : 40.00031661987305 seconds
# acc: 93.06 best_acc: 93.38
#
#
#
# Epoch 96 / 200: avg. loss of last 5 iterations 0.02440157575183548 , Time : 39.74867868423462 seconds
# acc: 93.29 best_acc: 93.38
#
#
#
# Epoch 97 / 200: avg. loss of last 5 iterations 0.015660855767782776 , Time : 39.86313724517822 seconds
# acc: 93.03 best_acc: 93.38
#
#
#
# Epoch 98 / 200: avg. loss of last 5 iterations 0.06527832451392897 , Time : 39.85964512825012 seconds
# acc: 92.98 best_acc: 93.38
#
#
#
# Epoch 99 / 200: avg. loss of last 5 iterations 0.004460457876848523 , Time : 39.74615693092346 seconds
# acc: 92.92 best_acc: 93.38
#
#
#
# Epoch 100 / 200: avg. loss of last 5 iterations 0.00954869487322867 , Time : 39.78337788581848 seconds
# acc: 93.27 best_acc: 93.38
#
#
#
# Epoch 101 / 200: avg. loss of last 5 iterations 0.0011897618212969973 , Time : 39.87743854522705 seconds
# acc: 93.4 best_acc: 93.38
# Saving..
#
#
#
# Epoch 102 / 200: avg. loss of last 5 iterations 0.0661715175374411 , Time : 39.82848644256592 seconds
# acc: 93.01 best_acc: 93.4
#
#
#
# Epoch 103 / 200: avg. loss of last 5 iterations 0.023571066011209042 , Time : 39.74314069747925 seconds
# acc: 92.7 best_acc: 93.4
#
#
#
# Epoch 104 / 200: avg. loss of last 5 iterations 0.025841637508710845 , Time : 39.81337547302246 seconds
# acc: 93.14 best_acc: 93.4
#
#
#
# Epoch 105 / 200: avg. loss of last 5 iterations 0.008334529614512576 , Time : 39.7513792514801 seconds
# acc: 92.96 best_acc: 93.4
#
#
#
# Epoch 106 / 200: avg. loss of last 5 iterations 0.009280548788956367 , Time : 39.704614877700806 seconds
# acc: 92.52 best_acc: 93.4
#
#
#
# Epoch 107 / 200: avg. loss of last 5 iterations 0.029019074165262282 , Time : 39.633583545684814 seconds
# acc: 92.97 best_acc: 93.4
#
#
#
# Epoch 108 / 200: avg. loss of last 5 iterations 0.03419801944401115 , Time : 39.75431561470032 seconds
# acc: 92.33 best_acc: 93.4
#
#
#
# Epoch 109 / 200: avg. loss of last 5 iterations 0.011387335462495684 , Time : 39.84727358818054 seconds
# acc: 92.94 best_acc: 93.4
#
#
#
# Epoch 110 / 200: avg. loss of last 5 iterations 0.003024627599370433 , Time : 39.834535121917725 seconds
# acc: 93.03 best_acc: 93.4
#
#
#
# Epoch 111 / 200: avg. loss of last 5 iterations 0.00958437252556905 , Time : 39.80528688430786 seconds
# acc: 93.1 best_acc: 93.4
#
#
#
# Epoch 112 / 200: avg. loss of last 5 iterations 0.0018946145108202472 , Time : 39.784669399261475 seconds
# acc: 93.12 best_acc: 93.4
#
#
#
# Epoch 113 / 200: avg. loss of last 5 iterations 0.013274089293554425 , Time : 39.88212704658508 seconds
# acc: 92.89 best_acc: 93.4
#
#
#
# Epoch 114 / 200: avg. loss of last 5 iterations 0.009967381926253438 , Time : 39.754167318344116 seconds
# acc: 93.07 best_acc: 93.4
#
#
#
# Epoch 115 / 200: avg. loss of last 5 iterations 0.005707754939794541 , Time : 39.86930704116821 seconds
# acc: 93.03 best_acc: 93.4
#
#
#
# Epoch 116 / 200: avg. loss of last 5 iterations 0.019457334661274216 , Time : 39.95145392417908 seconds
# acc: 93.16 best_acc: 93.4
#
#
#
# Epoch 117 / 200: avg. loss of last 5 iterations 0.012593155982904137 , Time : 39.835556983947754 seconds
# acc: 92.98 best_acc: 93.4
#
#
#
# Epoch 118 / 200: avg. loss of last 5 iterations 0.0377578908810392 , Time : 39.89573121070862 seconds
# acc: 92.59 best_acc: 93.4
#
#
#
# Epoch 119 / 200: avg. loss of last 5 iterations 0.005357862845994532 , Time : 39.7926926612854 seconds
# acc: 93.12 best_acc: 93.4
#
#
#
# Epoch 120 / 200: avg. loss of last 5 iterations 0.02064747172407806 , Time : 39.924662351608276 seconds
# acc: 92.86 best_acc: 93.4
#
#
#
# Epoch 121 / 200: avg. loss of last 5 iterations 0.002699727742583491 , Time : 39.79660725593567 seconds
# acc: 93.59 best_acc: 93.4
# Saving..
#
#
#
# Epoch 122 / 200: avg. loss of last 5 iterations 0.0014641476329416037 , Time : 39.848440408706665 seconds
# acc: 93.65 best_acc: 93.59
# Saving..
#
#
#
# Epoch 123 / 200: avg. loss of last 5 iterations 0.001436301026842557 , Time : 39.85328555107117 seconds
# acc: 93.74 best_acc: 93.65
# Saving..
#
#
#
# Epoch 124 / 200: avg. loss of last 5 iterations 0.0013364596175961196 , Time : 39.92360258102417 seconds
# acc: 93.76 best_acc: 93.74
# Saving..
#
#
#
# Epoch 125 / 200: avg. loss of last 5 iterations 0.0009889056265819818 , Time : 39.76639676094055 seconds
# acc: 93.86 best_acc: 93.76
# Saving..
#
#
#
# Epoch 126 / 200: avg. loss of last 5 iterations 0.0013528483294066973 , Time : 39.89932179450989 seconds
# acc: 93.91 best_acc: 93.86
# Saving..
#
#
#
# Epoch 127 / 200: avg. loss of last 5 iterations 0.0004184494697256014 , Time : 39.92927622795105 seconds
# acc: 93.83 best_acc: 93.91
#
#
#
# Epoch 128 / 200: avg. loss of last 5 iterations 0.0010294878025888464 , Time : 39.872151613235474 seconds
# acc: 93.94 best_acc: 93.91
# Saving..
#
#
#
# Epoch 129 / 200: avg. loss of last 5 iterations 0.001050318730995059 , Time : 39.83945846557617 seconds
# acc: 93.91 best_acc: 93.94
#
#
#
# Epoch 130 / 200: avg. loss of last 5 iterations 0.0029291166400071235 , Time : 40.067816734313965 seconds
# acc: 93.96 best_acc: 93.94
# Saving..
#
#
#
# Epoch 131 / 200: avg. loss of last 5 iterations 0.005783012518077157 , Time : 39.856292486190796 seconds
# acc: 93.9 best_acc: 93.96
#
#
#
# Epoch 132 / 200: avg. loss of last 5 iterations 0.0013943038356956095 , Time : 39.93925595283508 seconds
# acc: 93.89 best_acc: 93.96
#
#
#
# Epoch 133 / 200: avg. loss of last 5 iterations 0.000489562057191506 , Time : 39.940317153930664 seconds
# acc: 93.87 best_acc: 93.96
#
#
#
# Epoch 134 / 200: avg. loss of last 5 iterations 0.012813173214090057 , Time : 39.84017062187195 seconds
# acc: 93.89 best_acc: 93.96
#
#
#
# Epoch 135 / 200: avg. loss of last 5 iterations 0.0004870357079198584 , Time : 39.9880154132843 seconds
# acc: 93.84 best_acc: 93.96
#
#
#
# Epoch 136 / 200: avg. loss of last 5 iterations 0.0002989580389112234 , Time : 39.852226972579956 seconds
# acc: 93.86 best_acc: 93.96
#
#
#
# Epoch 137 / 200: avg. loss of last 5 iterations 0.0016419952458818442 , Time : 39.891925573349 seconds
# acc: 93.86 best_acc: 93.96
#
#
#
# Epoch 138 / 200: avg. loss of last 5 iterations 0.00014563668810296804 , Time : 39.86112856864929 seconds
# acc: 93.91 best_acc: 93.96
#
#
#
# Epoch 139 / 200: avg. loss of last 5 iterations 0.00047491366567555817 , Time : 39.824317932128906 seconds
# acc: 93.79 best_acc: 93.96
#
#
#
# Epoch 140 / 200: avg. loss of last 5 iterations 0.0002363419560424518 , Time : 39.91973876953125 seconds
# acc: 93.84 best_acc: 93.96
#
#
#
# Epoch 141 / 200: avg. loss of last 5 iterations 0.0009836918819928543 , Time : 39.875083684921265 seconds
# acc: 93.83 best_acc: 93.96
#
#
#
# Epoch 142 / 200: avg. loss of last 5 iterations 0.0003835206327494234 , Time : 39.928693771362305 seconds
# acc: 93.68 best_acc: 93.96
#
#
#
# Epoch 143 / 200: avg. loss of last 5 iterations 0.0013350772627745756 , Time : 39.89914393424988 seconds
# acc: 93.81 best_acc: 93.96
#
#
#
# Epoch 144 / 200: avg. loss of last 5 iterations 0.0006851584155810996 , Time : 39.84162449836731 seconds
# acc: 93.81 best_acc: 93.96
#
#
#
# Epoch 145 / 200: avg. loss of last 5 iterations 0.005935346832848154 , Time : 39.78281116485596 seconds
# acc: 93.95 best_acc: 93.96
#
#
#
# Epoch 146 / 200: avg. loss of last 5 iterations 0.00036920772836310787 , Time : 39.858362674713135 seconds
# acc: 93.9 best_acc: 93.96
#
#
#
# Epoch 147 / 200: avg. loss of last 5 iterations 7.327756211452651e-05 , Time : 39.758153438568115 seconds
# acc: 93.85 best_acc: 93.96
#
#
#
# Epoch 148 / 200: avg. loss of last 5 iterations 0.00037187588750384746 , Time : 39.842949867248535 seconds
# acc: 93.92 best_acc: 93.96
#
#
#
# Epoch 149 / 200: avg. loss of last 5 iterations 0.00036318599013611673 , Time : 39.80514621734619 seconds
# acc: 93.86 best_acc: 93.96
#
#
#
# Epoch 150 / 200: avg. loss of last 5 iterations 0.00024560952006140723 , Time : 39.871564626693726 seconds
# acc: 93.96 best_acc: 93.96
#
#
#
# Epoch 151 / 200: avg. loss of last 5 iterations 0.00019313976808916778 , Time : 39.89553785324097 seconds
# acc: 93.88 best_acc: 93.96
#
#
#
# Epoch 152 / 200: avg. loss of last 5 iterations 0.0004929135509883053 , Time : 39.945183515548706 seconds
# acc: 93.93 best_acc: 93.96
#
#
#
# Epoch 153 / 200: avg. loss of last 5 iterations 0.0007355025176366325 , Time : 40.014041900634766 seconds
# acc: 93.92 best_acc: 93.96
#
#
#
# Epoch 154 / 200: avg. loss of last 5 iterations 0.00011532951903063804 , Time : 39.84296631813049 seconds
# acc: 93.96 best_acc: 93.96
#
#
#
# Epoch 155 / 200: avg. loss of last 5 iterations 0.0003257817046687705 , Time : 39.64623522758484 seconds
# acc: 93.97 best_acc: 93.96
# Saving..
#
#
#
# Epoch 156 / 200: avg. loss of last 5 iterations 0.0001669172659603646 , Time : 39.63252592086792 seconds
# acc: 94.02 best_acc: 93.97
# Saving..
#
#
#
# Epoch 157 / 200: avg. loss of last 5 iterations 0.0005728947442548815 , Time : 39.72280430793762 seconds
# acc: 93.86 best_acc: 94.02
#
#
#
# Epoch 158 / 200: avg. loss of last 5 iterations 0.00011753406070056372 , Time : 39.663278579711914 seconds
# acc: 94.02 best_acc: 94.02
#
#
#
# Epoch 159 / 200: avg. loss of last 5 iterations 0.00029229901265352963 , Time : 39.77038073539734 seconds
# acc: 93.93 best_acc: 94.02
#
#
#
# Epoch 160 / 200: avg. loss of last 5 iterations 0.00016897764580789954 , Time : 39.66545605659485 seconds
# acc: 93.91 best_acc: 94.02
#
#
#
# Epoch 161 / 200: avg. loss of last 5 iterations 0.00019430551838013345 , Time : 39.688297510147095 seconds
# acc: 93.96 best_acc: 94.02
#
#
#
# Epoch 162 / 200: avg. loss of last 5 iterations 0.0009790765354409814 , Time : 39.62579345703125 seconds
# acc: 93.92 best_acc: 94.02
#
#
#
# Epoch 163 / 200: avg. loss of last 5 iterations 0.0007414199091726914 , Time : 39.703728437423706 seconds
# acc: 93.79 best_acc: 94.02
#
#
#
# Epoch 164 / 200: avg. loss of last 5 iterations 0.00029538038288592363 , Time : 39.743632555007935 seconds
# acc: 93.87 best_acc: 94.02
#
#
#
# Epoch 165 / 200: avg. loss of last 5 iterations 0.0006097925506765023 , Time : 39.76524090766907 seconds
# acc: 93.89 best_acc: 94.02
#
#
#
# Epoch 166 / 200: avg. loss of last 5 iterations 0.0007394230691716075 , Time : 39.69348621368408 seconds
# acc: 93.82 best_acc: 94.02
#
#
#
# Epoch 167 / 200: avg. loss of last 5 iterations 0.00011124202046630671 , Time : 39.682451248168945 seconds
# acc: 93.83 best_acc: 94.02
#
#
#
# Epoch 168 / 200: avg. loss of last 5 iterations 0.0008167440144461579 , Time : 39.67718577384949 seconds
# acc: 93.84 best_acc: 94.02
#
#
#
# Epoch 169 / 200: avg. loss of last 5 iterations 0.00033879725888255054 , Time : 39.66954731941223 seconds
# acc: 93.88 best_acc: 94.02
#
#
#
# Epoch 170 / 200: avg. loss of last 5 iterations 0.0003003963502123952 , Time : 39.7208526134491 seconds
# acc: 93.76 best_acc: 94.02
#
#
#
# Epoch 171 / 200: avg. loss of last 5 iterations 0.0009704794276331086 , Time : 39.732590198516846 seconds
# acc: 93.76 best_acc: 94.02
#
#
#
# Epoch 172 / 200: avg. loss of last 5 iterations 0.00015051889677124563 , Time : 39.69041967391968 seconds
# acc: 93.84 best_acc: 94.02
#
#
#
# Epoch 173 / 200: avg. loss of last 5 iterations 0.00010263912990922108 , Time : 39.575392961502075 seconds
# acc: 93.77 best_acc: 94.02
#
#
#
# Epoch 174 / 200: avg. loss of last 5 iterations 0.0004442324929186725 , Time : 39.60202503204346 seconds
# acc: 93.86 best_acc: 94.02
#
#
#
# Epoch 175 / 200: avg. loss of last 5 iterations 0.0002133079084160272 , Time : 39.574912309646606 seconds
# acc: 93.86 best_acc: 94.02
#
#
#
# Epoch 176 / 200: avg. loss of last 5 iterations 0.00020902813666907606 , Time : 39.60481667518616 seconds
# acc: 93.9 best_acc: 94.02
#
#
#
# Epoch 177 / 200: avg. loss of last 5 iterations 0.00020499551319517196 , Time : 39.72356104850769 seconds
# acc: 93.88 best_acc: 94.02
#
#
#
# Epoch 178 / 200: avg. loss of last 5 iterations 0.00017021769162965937 , Time : 39.689749002456665 seconds
# acc: 93.75 best_acc: 94.02
#
#
#
# Epoch 179 / 200: avg. loss of last 5 iterations 0.00026413882151246073 , Time : 39.67961239814758 seconds
# acc: 94.0 best_acc: 94.02
#
#
#
# Epoch 180 / 200: avg. loss of last 5 iterations 8.204552323149983e-05 , Time : 39.68956661224365 seconds
# acc: 93.96 best_acc: 94.02
#
#
#
# Epoch 181 / 200: avg. loss of last 5 iterations 0.00020349117839941756 , Time : 39.608556509017944 seconds
# acc: 93.98 best_acc: 94.02
#
#
#
# Epoch 182 / 200: avg. loss of last 5 iterations 0.0005565967629081569 , Time : 39.679460525512695 seconds
# acc: 93.94 best_acc: 94.02
#
#
#
# Epoch 183 / 200: avg. loss of last 5 iterations 0.00028791469012503514 , Time : 39.6816291809082 seconds
# acc: 93.99 best_acc: 94.02
#
#
#
# Epoch 184 / 200: avg. loss of last 5 iterations 0.0003661352631752379 , Time : 39.659284830093384 seconds
# acc: 93.97 best_acc: 94.02
#
#
#
# Epoch 185 / 200: avg. loss of last 5 iterations 0.0003503958025248721 , Time : 39.75132393836975 seconds
# acc: 94.0 best_acc: 94.02
#
#
#
# Epoch 186 / 200: avg. loss of last 5 iterations 0.00020580941381922457 , Time : 39.62598514556885 seconds
# acc: 93.96 best_acc: 94.02
#
#
#
# Epoch 187 / 200: avg. loss of last 5 iterations 7.563536310044583e-05 , Time : 39.64755439758301 seconds
# acc: 93.99 best_acc: 94.02
#
#
#
# Epoch 188 / 200: avg. loss of last 5 iterations 0.0004192490217974409 , Time : 39.774447202682495 seconds
# acc: 93.98 best_acc: 94.02
#
#
#
# Epoch 189 / 200: avg. loss of last 5 iterations 0.00011498096137074754 , Time : 39.641242027282715 seconds
# acc: 93.96 best_acc: 94.02
#
#
#
# Epoch 190 / 200: avg. loss of last 5 iterations 0.00022778032289352267 , Time : 39.54786777496338 seconds
# acc: 93.98 best_acc: 94.02
#
#
#
# Epoch 191 / 200: avg. loss of last 5 iterations 0.00022409325392800384 , Time : 39.67362856864929 seconds
# acc: 93.97 best_acc: 94.02
#
#
#
# Epoch 192 / 200: avg. loss of last 5 iterations 9.692527310107834e-05 , Time : 39.58747673034668 seconds
# acc: 93.97 best_acc: 94.02
#
#
#
# Epoch 193 / 200: avg. loss of last 5 iterations 0.0006213654818566283 , Time : 39.68899583816528 seconds
# acc: 93.95 best_acc: 94.02
#
#
#
# Epoch 194 / 200: avg. loss of last 5 iterations 7.68594722103444e-05 , Time : 39.712661266326904 seconds
# acc: 93.96 best_acc: 94.02
#
#
#
# Epoch 195 / 200: avg. loss of last 5 iterations 0.0015080886922078207 , Time : 39.681108474731445 seconds
# acc: 93.94 best_acc: 94.02
#
#
#
# Epoch 196 / 200: avg. loss of last 5 iterations 0.00012126642031944357 , Time : 39.692325592041016 seconds
# acc: 93.93 best_acc: 94.02
#
#
#
# Epoch 197 / 200: avg. loss of last 5 iterations 0.0003118915454251692 , Time : 39.820708990097046 seconds
# acc: 93.91 best_acc: 94.02
#
#
#
# Epoch 198 / 200: avg. loss of last 5 iterations 0.00017183753952849657 , Time : 39.730682373046875 seconds
# acc: 93.91 best_acc: 94.02
#
#
#
# Epoch 199 / 200: avg. loss of last 5 iterations 7.461867662641452e-05 , Time : 39.60795593261719 seconds
# acc: 93.96 best_acc: 94.02
#
#
#
# Epoch 200 / 200: avg. loss of last 5 iterations 0.004510457081778441 , Time : 39.72385025024414 seconds
# acc: 93.95 best_acc: 94.02

# %% [markdown]
# ### 4.3 The Loss Curve
# Loss curve is visualized.

# %%
plt.plot(loss_history)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# ### 4.4 Quantitative Analysis
#
# We can analyze the accuracy of the predictions as follows.

# %%
correct = 0
total = 0
with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(testloader):
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = net(inputs)
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 93 %

# %%
print('saving' ,'acc:',best_acc)
# Out:
# saving acc: 94.02

# %% [markdown]
# ### 5 Results
#
# Accuracy vs epoch is plotted according to the test results.

# %%
plt.plot(historyy)
plt.xlabel('Epoch number')
plt.ylabel('Accuracy')
plt.show()
print(historyy)
# Out:
# [30.77, 42.43, 51.78, 56.15, 67.66, 71.68, 74.96, 73.8, 79.32, 79.34, 80.44, 82.26, 81.06, 83.16, 83.72, 83.03, 83.73, 84.22, 85.37, 84.66, 84.76, 85.86, 85.1, 86.16, 84.32, 86.6, 84.78, 86.97, 86.41, 86.35, 88.74, 85.82, 88.05, 87.89, 88.94, 87.02, 88.69, 88.04, 87.7, 86.37, 87.22, 87.21, 88.33, 83.03, 86.93, 88.88, 88.25, 87.3, 89.29, 86.78, 86.14, 87.35, 87.84, 87.04, 88.53, 87.98, 88.07, 88.16, 86.06, 89.74, 92.62, 92.62, 93.03, 92.77, 92.95, 93.01, 93.01, 92.77, 92.92, 93.1, 92.86, 92.84, 93.25, 92.86, 93.36, 93.27, 93.38, 92.92, 93.06, 93.28, 93.25, 93.12, 93.21, 93.1, 93.28, 93.18, 93.2, 92.99, 93.01, 93.33, 93.21, 93.0, 93.17, 93.24, 93.06, 93.29, 93.03, 92.98, 92.92, 93.27, 93.4, 93.01, 92.7, 93.14, 92.96, 92.52, 92.97, 92.33, 92.94, 93.03, 93.1, 93.12, 92.89, 93.07, 93.03, 93.16, 92.98, 92.59, 93.12, 92.86, 93.59, 93.65, 93.74, 93.76, 93.86, 93.91, 93.83, 93.94, 93.91, 93.96, 93.9, 93.89, 93.87, 93.89, 93.84, 93.86, 93.86, 93.91, 93.79, 93.84, 93.83, 93.68, 93.81, 93.81, 93.95, 93.9, 93.85, 93.92, 93.86, 93.96, 93.88, 93.93, 93.92, 93.96, 93.97, 94.02, 93.86, 94.02, 93.93, 93.91, 93.96, 93.92, 93.79, 93.87, 93.89, 93.82, 93.83, 93.84, 93.88, 93.76, 93.76, 93.84, 93.77, 93.86, 93.86, 93.9, 93.88, 93.75, 94.0, 93.96, 93.98, 93.94, 93.99, 93.97, 94.0, 93.96, 93.99, 93.98, 93.96, 93.98, 93.97, 93.97, 93.95, 93.96, 93.94, 93.93, 93.91, 93.91, 93.96, 93.95]
